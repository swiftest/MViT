# %%
import os
import time
import math
import argparse
import numpy as np
import scipy.io as sio
import matplotlib as mpl
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler


import torch
import torch.nn as nn
from torch import optim
import torch.utils.data as Data
import torch.nn.functional as F
from torchsummary import summary
from einops import rearrange, repeat
from timm.models.vision_transformer import Block


from data_prepare import mirror_hsi
from data_prepare import choose_train_and_test
from data_prepare import choose_all_pixels, all_data
from data_prepare import train_and_test_data, train_and_test_label


from Utils import output_metric, plot_confusion_matrix
from CNNUtils import train, test, valid
from Utils import list_to_colormap, classification_map, print_args


# %matplotlib inline

# %%
parser = argparse.ArgumentParser("MaskedFormer")
parser.add_argument('--dataset', choices=['LongKou', 'HanChuan', 'HongHu', 'Pavia'], default='Pavia', help='dataset to use')
parser.add_argument('--seed', type=int, default=42, help='number of seed')
parser.add_argument('--batch_size', type=int, default=30, help='number of batch size')
parser.add_argument('--patch_size', type=int, default=15, help='size of patches')
parser.add_argument('--epoches', type=int, default=100, help='epoch number')
parser.add_argument('--learning_rate', type=float, default=1e-3, help='learning rate')
parser.add_argument('--gamma', type=float, default=0.99, help='gamma')
parser.add_argument('--weight_decay', type=float, default=0.001, help='weight_decay')
parser.add_argument('--train_number', type=int, default=25, help='num_train_per_class')
args = parser.parse_args(args=[])

# %%
# prepare data
data_path = os.path.join(os.getcwd(), 'dataset')

if args.dataset == 'LongKou':
    data = sio.loadmat(os.path.join(data_path, 'WHU_Hi_LongKou.mat'))['WHU_Hi_LongKou']
    label = sio.loadmat(os.path.join(data_path, 'WHU_Hi_LongKou_gt.mat'))['WHU_Hi_LongKou_gt']
elif args.dataset == 'HanChuan':
    data = sio.loadmat(os.path.join(data_path, 'WHU_Hi_HanChuan.mat'))['WHU_Hi_HanChuan']
    label = sio.loadmat(os.path.join(data_path, 'WHU_Hi_HanChuan_gt.mat'))['WHU_Hi_HanChuan_gt']
elif args.dataset == 'HongHu':
    data = sio.loadmat(os.path.join(data_path, 'WHU_Hi_HongHu.mat'))['WHU_Hi_HongHu']
    label = sio.loadmat(os.path.join(data_path, 'WHU_Hi_HongHu_gt.mat'))['WHU_Hi_HongHu_gt']
elif args.dataset == 'Pavia':
    data = sio.loadmat(os.path.join(data_path, 'PaviaU.mat'))['paviaU']
    label = sio.loadmat(os.path.join(data_path, 'PaviaU_gt.mat'))['paviaU_gt']
else:
    raise ValueError("Unknown dataset")
    
num_classes = np.max(label)
print('The class numbers of the HSI data is:', num_classes)
# Out:
# The class numbers of the HSI data is: 9

# %%
shapeor = data.shape
data = data.reshape(np.prod(data.shape[:2]), np.prod(data.shape[2:]))

std_scaler = StandardScaler()
std_data = std_scaler.fit_transform(data)
data = std_data.reshape(shapeor)

# %%
def applyPCA(data, numComponents=30):
    new_data = np.reshape(data, (-1, data.shape[2]))
    pca = PCA(n_components=numComponents, whiten=True)
    new_data = pca.fit_transform(new_data)
    new_data = np.reshape(new_data, (data.shape[0], data.shape[1], numComponents))
    return new_data, pca

# %%
K = 30
data, pca = applyPCA(data, numComponents=K)

# data size
height, width, band = data.shape
print("height={0}, width={1}, band={2}".format(height, width, band))
# Out:
# height=610, width=340, band=30

# %%
mirror_data = mirror_hsi(height, width, band, data, patch_size=args.patch_size)
# Out:
# *******************************************************
# patch_size : 15
# mirror_data shape : [624, 354, 30]
# *******************************************************

# %%
total_pos_train, total_pos_test, total_pos_valid, number_train, number_test, number_valid = choose_train_and_test(label, args.train_number, args.seed) 

x_train, x_test, x_valid = train_and_test_data(mirror_data, band, total_pos_train, total_pos_test, total_pos_valid, args.patch_size)
y_train, y_test, y_valid = train_and_test_label(number_train, number_test, number_valid, num_classes)
# Out:
# *******************************************************
# x_train shape = (225, 15, 15, 30), type = float64
# x_test  shape = (42551, 15, 15, 30), type = float64
# x_valid  shape = (900, 15, 15, 30), type = float64
# *******************************************************
# y_train: shape = (225,), type = int64
# y_test: shape = (42551,), type = int64
# y_valid: shape = (900,), type = int64
# *******************************************************

# %%
total_pos_train[:10]
# Out:
# array([[409, 293],
#        [404, 298],
#        [380, 301],
#        [551,  14],
#        [453, 165],
#        [140, 172],
#        [471, 169],
#        [175, 187],
#        [482, 185],
#        [214, 200]])

# %%
# load data
x_train = torch.from_numpy(x_train.transpose(0, 3, 1, 2)).type(torch.FloatTensor)  # (90, 30, 15, 15)
print(x_train.shape)
y_train = torch.from_numpy(y_train).type(torch.LongTensor)  # (13,)
train_label = Data.TensorDataset(x_train, y_train)

x_test = torch.from_numpy(x_test.transpose(0, 3, 1, 2)).type(torch.FloatTensor)  # (5198, 30, 15, 15)
print(x_test.shape)
y_test = torch.from_numpy(y_test).type(torch.LongTensor)  # (5198,)
test_label = Data.TensorDataset(x_test, y_test)

x_valid = torch.from_numpy(x_valid.transpose(0, 3, 1, 2)).type(torch.FloatTensor)  # (5211, 30, 15, 15)
print(x_valid.shape)
y_valid = torch.from_numpy(y_valid).type(torch.LongTensor)
valid_label = Data.TensorDataset(x_valid, y_valid)

train_loader = Data.DataLoader(train_label, batch_size=30, shuffle=True)
test_loader = Data.DataLoader(test_label, batch_size=128, shuffle=True)
valid_loader = Data.DataLoader(valid_label, batch_size=64, shuffle=True)
# Out:
# torch.Size([225, 30, 15, 15])
# torch.Size([42551, 30, 15, 15])
# torch.Size([900, 30, 15, 15])

# %% [markdown]
# ## Model

# %%
class GroupedPixelEmbedding(nn.Module):
    def __init__(self, in_chans, embed_dim, n_groups):
        super(GroupedPixelEmbedding, self).__init__()
        self.proj = nn.Conv2d(in_chans, embed_dim, kernel_size=3, stride=1, padding=1, groups=n_groups)
        self.batch_norm = nn.BatchNorm2d(embed_dim)
        self.relu = nn.ReLU(inplace=True)

    def forward(self, x):
        x = self.proj(x)
        x = self.relu(self.batch_norm(x))
        x = x.flatten(2).transpose(1, 2)
        return x


class GAHT(nn.Module):
    def __init__(self, in_chans=30, num_classes=9, num_stages=3, n_groups=[32, 32, 32], embed_dims=[256, 128, 64], num_heads=[8, 4, 2], depths=[1, 2, 1]):
        super(GAHT, self).__init__()
        self.num_stages = num_stages

        new_bands = math.ceil(in_chans / n_groups[0]) * n_groups[0]
        self.pad = nn.ReplicationPad3d((0, 0, 0, 0, 0, new_bands - in_chans))
        
        for i in range(num_stages):
            patch_embed = GroupedPixelEmbedding(in_chans=new_bands if i == 0 else embed_dims[i - 1], embed_dim=embed_dims[i], n_groups=n_groups[i])

            block = nn.ModuleList([Block(embed_dims[i], num_heads[i], mlp_ratio=1, drop=0., attn_drop=0.) for j in range(depths[i])])
            
            norm = nn.LayerNorm(embed_dims[i])

            setattr(self, f"patch_embed{i + 1}", patch_embed)
            setattr(self, f"block{i + 1}", block)
            setattr(self, f"norm{i + 1}", norm)
        
        self.head = nn.Linear(embed_dims[-1], num_classes) 

    def forward(self, x):
        # x: (B, 30, 15, 15)
        x = self.pad(x)  # (B, 32, 15, 15)
        assert x.shape[2] == x.shape[3]
        B, s = x.shape[0], x.shape[2]
        
        for i in range(self.num_stages):
            patch_embed = getattr(self, f"patch_embed{i + 1}")
            block = getattr(self, f"block{i + 1}")
            norm = getattr(self, f"norm{i + 1}")
            
            x = patch_embed(x)  # (B, 225, 256)
            for blk in block:
                x = blk(x)
            x = norm(x)

            if i != self.num_stages - 1: 
                x = x.reshape(B, s, s, -1).permute(0, 3, 1, 2).contiguous()
        
        x = x.mean(dim=1)
        x = self.head(x)
        return x

# %%
def model_summary(model):
    total_param = 0
    for name, param in model.named_parameters():
        if param.requires_grad:
            num_param = np.prod(param.size())
            if param.dim() > 1:
                print(name+':', 'x'.join(str(x) for x in list(param.size())), '=', num_param)
            else:
                print(name+':', num_param)
            total_param += num_param
    print("\nTotal Trainable Parameters:", total_param)

# %%
model = GAHT(num_classes=num_classes).cuda()

criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=1e-3, betas=(0.9, 0.999), eps=1e-8, weight_decay=0)
scheduler = optim.lr_scheduler.ExponentialLR(optimizer, gamma=args.gamma)

# %%
print('start training')
acc_list = [0.00]
path = './model/GAHT.pt'
tic = time.time()
for epoch in range(args.epoches):
    # 计算的是移动平均准确率
    train_acc, train_loss = train(model, train_loader, criterion, optimizer)
    valid_acc, valid_loss = valid(model, valid_loader, criterion)
    print("Epoch: {:03d} - train_loss: {:.4f} - train_acc: {:.4f} - valid_loss: {:.4f} - valid_acc: {:.4f}".\
          format(epoch+1, train_loss, train_acc, valid_loss, valid_acc))
    scheduler.step()

    acc_list.append(valid_acc)
    if acc_list[-1] > acc_list[-2]:
        print("val_acc improved from {:.4f} to {:.4f}, saving model to GAHT.pt".format(acc_list[-2], acc_list[-1]))
        torch.save(model.state_dict(), path)
    else:
        print("val_acc did not improve from {:.4f}".format(acc_list[-2]))
        acc_list[-1] = acc_list[-2]

toc = time.time()
print("Running Time: {:.2f}".format(toc-tic))
print("**************************************************")
# Out:
# start training
# Epoch: 001 - train_loss: 1.4288 - train_acc: 61.3333 - valid_loss: 0.8483 - valid_acc: 77.0000
# val_acc improved from 0.0000 to 77.0000, saving model to GAHT.pt
# Epoch: 002 - train_loss: 0.6852 - train_acc: 85.3333 - valid_loss: 0.5469 - valid_acc: 85.6667
# val_acc improved from 77.0000 to 85.6667, saving model to GAHT.pt
# Epoch: 003 - train_loss: 0.4791 - train_acc: 91.5556 - valid_loss: 0.4176 - valid_acc: 89.4445
# val_acc improved from 85.6667 to 89.4445, saving model to GAHT.pt
# Epoch: 004 - train_loss: 0.2999 - train_acc: 96.4445 - valid_loss: 0.3837 - valid_acc: 88.7778
# val_acc did not improve from 89.4445
# Epoch: 005 - train_loss: 0.2215 - train_acc: 95.1111 - valid_loss: 0.3500 - valid_acc: 89.7778
# val_acc improved from 89.4445 to 89.7778, saving model to GAHT.pt
# Epoch: 006 - train_loss: 0.2054 - train_acc: 94.6667 - valid_loss: 0.3848 - valid_acc: 89.1111
# val_acc did not improve from 89.7778
# Epoch: 007 - train_loss: 0.1963 - train_acc: 95.5556 - valid_loss: 0.2660 - valid_acc: 92.4445
# val_acc improved from 89.7778 to 92.4445, saving model to GAHT.pt
# Epoch: 008 - train_loss: 0.1873 - train_acc: 94.2222 - valid_loss: 0.3393 - valid_acc: 89.5556
# val_acc did not improve from 92.4445
# Epoch: 009 - train_loss: 0.1422 - train_acc: 97.3333 - valid_loss: 0.2855 - valid_acc: 91.5556
# val_acc did not improve from 92.4445
# Epoch: 010 - train_loss: 0.1952 - train_acc: 94.6667 - valid_loss: 0.3736 - valid_acc: 88.5556
# val_acc did not improve from 92.4445
# Epoch: 011 - train_loss: 0.1143 - train_acc: 96.8889 - valid_loss: 0.3397 - valid_acc: 89.3333
# val_acc did not improve from 92.4445
# Epoch: 012 - train_loss: 0.0632 - train_acc: 100.0000 - valid_loss: 0.3790 - valid_acc: 88.8889
# val_acc did not improve from 92.4445
# Epoch: 013 - train_loss: 0.0960 - train_acc: 98.2222 - valid_loss: 0.2317 - valid_acc: 93.4445
# val_acc improved from 92.4445 to 93.4445, saving model to GAHT.pt
# Epoch: 014 - train_loss: 0.1016 - train_acc: 98.2222 - valid_loss: 0.3543 - valid_acc: 89.5556
# val_acc did not improve from 93.4445
# Epoch: 015 - train_loss: 0.0706 - train_acc: 97.7778 - valid_loss: 0.4083 - valid_acc: 88.8889
# val_acc did not improve from 93.4445
# Epoch: 016 - train_loss: 0.0468 - train_acc: 98.6667 - valid_loss: 0.2837 - valid_acc: 91.0000
# val_acc did not improve from 93.4445
# Epoch: 017 - train_loss: 0.0271 - train_acc: 100.0000 - valid_loss: 0.2381 - valid_acc: 92.3333
# val_acc did not improve from 93.4445
# Epoch: 018 - train_loss: 0.0878 - train_acc: 98.2222 - valid_loss: 0.2425 - valid_acc: 93.0000
# val_acc did not improve from 93.4445
# Epoch: 019 - train_loss: 0.0509 - train_acc: 98.6667 - valid_loss: 0.2019 - valid_acc: 93.3333
# val_acc did not improve from 93.4445
# Epoch: 020 - train_loss: 0.0434 - train_acc: 99.5556 - valid_loss: 0.2247 - valid_acc: 93.7778
# val_acc improved from 93.4445 to 93.7778, saving model to GAHT.pt
# Epoch: 021 - train_loss: 0.0593 - train_acc: 98.6667 - valid_loss: 0.2723 - valid_acc: 91.5556
# val_acc did not improve from 93.7778
# Epoch: 022 - train_loss: 0.0391 - train_acc: 99.1111 - valid_loss: 0.2488 - valid_acc: 92.6667
# val_acc did not improve from 93.7778
# Epoch: 023 - train_loss: 0.0320 - train_acc: 99.5556 - valid_loss: 0.2898 - valid_acc: 92.0000
# val_acc did not improve from 93.7778
# Epoch: 024 - train_loss: 0.1262 - train_acc: 96.8889 - valid_loss: 0.2350 - valid_acc: 93.3333
# val_acc did not improve from 93.7778
# Epoch: 025 - train_loss: 0.0681 - train_acc: 99.1111 - valid_loss: 0.3641 - valid_acc: 89.0000
# val_acc did not improve from 93.7778
# Epoch: 026 - train_loss: 0.0358 - train_acc: 99.5556 - valid_loss: 0.3382 - valid_acc: 90.8889
# val_acc did not improve from 93.7778
# Epoch: 027 - train_loss: 0.0823 - train_acc: 97.3333 - valid_loss: 0.2947 - valid_acc: 91.8889
# val_acc did not improve from 93.7778
# Epoch: 028 - train_loss: 0.0903 - train_acc: 97.3333 - valid_loss: 0.2753 - valid_acc: 92.5556
# val_acc did not improve from 93.7778
# Epoch: 029 - train_loss: 0.0356 - train_acc: 99.5556 - valid_loss: 0.2425 - valid_acc: 92.7778
# val_acc did not improve from 93.7778
# Epoch: 030 - train_loss: 0.0289 - train_acc: 99.1111 - valid_loss: 0.2427 - valid_acc: 93.1111
# val_acc did not improve from 93.7778
# Epoch: 031 - train_loss: 0.0343 - train_acc: 99.5556 - valid_loss: 0.2522 - valid_acc: 93.0000
# val_acc did not improve from 93.7778
# Epoch: 032 - train_loss: 0.0248 - train_acc: 100.0000 - valid_loss: 0.4854 - valid_acc: 88.2222
# val_acc did not improve from 93.7778
# Epoch: 033 - train_loss: 0.0155 - train_acc: 100.0000 - valid_loss: 0.3121 - valid_acc: 91.6667
# val_acc did not improve from 93.7778
# Epoch: 034 - train_loss: 0.0153 - train_acc: 99.5556 - valid_loss: 0.3655 - valid_acc: 90.7778
# val_acc did not improve from 93.7778
# Epoch: 035 - train_loss: 0.0156 - train_acc: 100.0000 - valid_loss: 0.3257 - valid_acc: 91.4445
# val_acc did not improve from 93.7778
# Epoch: 036 - train_loss: 0.0111 - train_acc: 100.0000 - valid_loss: 0.3087 - valid_acc: 92.2222
# val_acc did not improve from 93.7778
# Epoch: 037 - train_loss: 0.0145 - train_acc: 100.0000 - valid_loss: 0.3596 - valid_acc: 91.5556
# val_acc did not improve from 93.7778
# Epoch: 038 - train_loss: 0.0187 - train_acc: 99.5556 - valid_loss: 0.2364 - valid_acc: 93.4445
# val_acc did not improve from 93.7778
# Epoch: 039 - train_loss: 0.0144 - train_acc: 99.5556 - valid_loss: 0.2438 - valid_acc: 93.5556
# val_acc did not improve from 93.7778
# Epoch: 040 - train_loss: 0.0113 - train_acc: 100.0000 - valid_loss: 0.2438 - valid_acc: 93.3333
# val_acc did not improve from 93.7778
# Epoch: 041 - train_loss: 0.0082 - train_acc: 100.0000 - valid_loss: 0.3542 - valid_acc: 91.7778
# val_acc did not improve from 93.7778
# Epoch: 042 - train_loss: 0.0164 - train_acc: 99.5556 - valid_loss: 0.3135 - valid_acc: 92.3333
# val_acc did not improve from 93.7778
# Epoch: 043 - train_loss: 0.0074 - train_acc: 100.0000 - valid_loss: 0.4482 - valid_acc: 89.1111
# val_acc did not improve from 93.7778
# Epoch: 044 - train_loss: 0.1005 - train_acc: 98.2222 - valid_loss: 0.3629 - valid_acc: 91.8889
# val_acc did not improve from 93.7778
# Epoch: 045 - train_loss: 0.0112 - train_acc: 100.0000 - valid_loss: 0.4125 - valid_acc: 89.6667
# val_acc did not improve from 93.7778
# Epoch: 046 - train_loss: 0.0285 - train_acc: 98.6667 - valid_loss: 0.3418 - valid_acc: 92.1111
# val_acc did not improve from 93.7778
# Epoch: 047 - train_loss: 0.0092 - train_acc: 100.0000 - valid_loss: 0.3522 - valid_acc: 91.6667
# val_acc did not improve from 93.7778
# Epoch: 048 - train_loss: 0.0066 - train_acc: 100.0000 - valid_loss: 0.3345 - valid_acc: 91.3333
# val_acc did not improve from 93.7778
# Epoch: 049 - train_loss: 0.0077 - train_acc: 100.0000 - valid_loss: 0.3211 - valid_acc: 92.2222
# val_acc did not improve from 93.7778
# Epoch: 050 - train_loss: 0.0062 - train_acc: 100.0000 - valid_loss: 0.2851 - valid_acc: 93.6667
# val_acc did not improve from 93.7778
# Epoch: 051 - train_loss: 0.0136 - train_acc: 99.5556 - valid_loss: 0.2856 - valid_acc: 93.6667
# val_acc did not improve from 93.7778
# Epoch: 052 - train_loss: 0.0061 - train_acc: 100.0000 - valid_loss: 0.2983 - valid_acc: 92.4445
# val_acc did not improve from 93.7778
# Epoch: 053 - train_loss: 0.0055 - train_acc: 100.0000 - valid_loss: 0.3035 - valid_acc: 92.5556
# val_acc did not improve from 93.7778
# Epoch: 054 - train_loss: 0.0047 - train_acc: 100.0000 - valid_loss: 0.3169 - valid_acc: 92.1111
# val_acc did not improve from 93.7778
# Epoch: 055 - train_loss: 0.0051 - train_acc: 100.0000 - valid_loss: 0.3077 - valid_acc: 92.3333
# val_acc did not improve from 93.7778
# Epoch: 056 - train_loss: 0.0071 - train_acc: 100.0000 - valid_loss: 0.2939 - valid_acc: 93.2222
# val_acc did not improve from 93.7778
# Epoch: 057 - train_loss: 0.0048 - train_acc: 100.0000 - valid_loss: 0.2519 - valid_acc: 93.6667
# val_acc did not improve from 93.7778
# Epoch: 058 - train_loss: 0.0044 - train_acc: 100.0000 - valid_loss: 0.2634 - valid_acc: 93.5556
# val_acc did not improve from 93.7778
# Epoch: 059 - train_loss: 0.0047 - train_acc: 100.0000 - valid_loss: 0.2520 - valid_acc: 93.7778
# val_acc did not improve from 93.7778
# Epoch: 060 - train_loss: 0.0042 - train_acc: 100.0000 - valid_loss: 0.2563 - valid_acc: 94.1111
# val_acc improved from 93.7778 to 94.1111, saving model to GAHT.pt
# Epoch: 061 - train_loss: 0.0049 - train_acc: 100.0000 - valid_loss: 0.2592 - valid_acc: 94.2222
# val_acc improved from 94.1111 to 94.2222, saving model to GAHT.pt
# Epoch: 062 - train_loss: 0.0040 - train_acc: 100.0000 - valid_loss: 0.2583 - valid_acc: 93.8889
# val_acc did not improve from 94.2222
# Epoch: 063 - train_loss: 0.0045 - train_acc: 100.0000 - valid_loss: 0.2870 - valid_acc: 93.0000
# val_acc did not improve from 94.2222
# Epoch: 064 - train_loss: 0.0074 - train_acc: 100.0000 - valid_loss: 0.2776 - valid_acc: 93.4445
# val_acc did not improve from 94.2222
# Epoch: 065 - train_loss: 0.0043 - train_acc: 100.0000 - valid_loss: 0.3562 - valid_acc: 91.1111
# val_acc did not improve from 94.2222
# Epoch: 066 - train_loss: 0.0111 - train_acc: 99.5556 - valid_loss: 0.3452 - valid_acc: 91.4445
# val_acc did not improve from 94.2222
# Epoch: 067 - train_loss: 0.0089 - train_acc: 100.0000 - valid_loss: 0.3391 - valid_acc: 91.5556
# val_acc did not improve from 94.2222
# Epoch: 068 - train_loss: 0.0077 - train_acc: 100.0000 - valid_loss: 0.2606 - valid_acc: 93.6667
# val_acc did not improve from 94.2222
# Epoch: 069 - train_loss: 0.0061 - train_acc: 100.0000 - valid_loss: 0.2474 - valid_acc: 94.0000
# val_acc did not improve from 94.2222
# Epoch: 070 - train_loss: 0.0082 - train_acc: 100.0000 - valid_loss: 0.2656 - valid_acc: 93.7778
# val_acc did not improve from 94.2222
# Epoch: 071 - train_loss: 0.0043 - train_acc: 100.0000 - valid_loss: 0.3836 - valid_acc: 92.7778
# val_acc did not improve from 94.2222
# Epoch: 072 - train_loss: 0.0037 - train_acc: 100.0000 - valid_loss: 0.4357 - valid_acc: 92.3333
# val_acc did not improve from 94.2222
# Epoch: 073 - train_loss: 0.0049 - train_acc: 100.0000 - valid_loss: 0.3981 - valid_acc: 92.8889
# val_acc did not improve from 94.2222
# Epoch: 074 - train_loss: 0.0032 - train_acc: 100.0000 - valid_loss: 0.3710 - valid_acc: 93.0000
# val_acc did not improve from 94.2222
# Epoch: 075 - train_loss: 0.0043 - train_acc: 100.0000 - valid_loss: 0.3653 - valid_acc: 93.0000
# val_acc did not improve from 94.2222
# Epoch: 076 - train_loss: 0.0054 - train_acc: 100.0000 - valid_loss: 0.3949 - valid_acc: 91.8889
# val_acc did not improve from 94.2222
# Epoch: 077 - train_loss: 0.0031 - train_acc: 100.0000 - valid_loss: 0.4147 - valid_acc: 91.3333
# val_acc did not improve from 94.2222
# Epoch: 078 - train_loss: 0.0170 - train_acc: 99.1111 - valid_loss: 0.3040 - valid_acc: 93.4445
# val_acc did not improve from 94.2222
# Epoch: 079 - train_loss: 0.0038 - train_acc: 100.0000 - valid_loss: 0.4474 - valid_acc: 91.0000
# val_acc did not improve from 94.2222
# Epoch: 080 - train_loss: 0.0058 - train_acc: 100.0000 - valid_loss: 0.4976 - valid_acc: 90.6667
# val_acc did not improve from 94.2222
# Epoch: 081 - train_loss: 0.0373 - train_acc: 99.5556 - valid_loss: 0.3095 - valid_acc: 93.5556
# val_acc did not improve from 94.2222
# Epoch: 082 - train_loss: 0.0041 - train_acc: 100.0000 - valid_loss: 0.2959 - valid_acc: 93.2222
# val_acc did not improve from 94.2222
# Epoch: 083 - train_loss: 0.0056 - train_acc: 100.0000 - valid_loss: 0.2904 - valid_acc: 93.3333
# val_acc did not improve from 94.2222
# Epoch: 084 - train_loss: 0.0194 - train_acc: 99.5556 - valid_loss: 0.5095 - valid_acc: 89.5556
# val_acc did not improve from 94.2222
# Epoch: 085 - train_loss: 0.0146 - train_acc: 99.5556 - valid_loss: 0.4056 - valid_acc: 91.0000
# val_acc did not improve from 94.2222
# Epoch: 086 - train_loss: 0.0053 - train_acc: 100.0000 - valid_loss: 0.3774 - valid_acc: 90.8889
# val_acc did not improve from 94.2222
# Epoch: 087 - train_loss: 0.0094 - train_acc: 99.5556 - valid_loss: 0.2736 - valid_acc: 93.4445
# val_acc did not improve from 94.2222
# Epoch: 088 - train_loss: 0.0034 - train_acc: 100.0000 - valid_loss: 0.2794 - valid_acc: 93.4445
# val_acc did not improve from 94.2222
# Epoch: 089 - train_loss: 0.0036 - train_acc: 100.0000 - valid_loss: 0.2927 - valid_acc: 93.2222
# val_acc did not improve from 94.2222
# Epoch: 090 - train_loss: 0.0032 - train_acc: 100.0000 - valid_loss: 0.2867 - valid_acc: 93.3333
# val_acc did not improve from 94.2222
# Epoch: 091 - train_loss: 0.0036 - train_acc: 100.0000 - valid_loss: 0.2840 - valid_acc: 93.1111
# val_acc did not improve from 94.2222
# Epoch: 092 - train_loss: 0.0028 - train_acc: 100.0000 - valid_loss: 0.2729 - valid_acc: 93.7778
# val_acc did not improve from 94.2222
# Epoch: 093 - train_loss: 0.0029 - train_acc: 100.0000 - valid_loss: 0.2800 - valid_acc: 93.4445
# val_acc did not improve from 94.2222
# Epoch: 094 - train_loss: 0.0025 - train_acc: 100.0000 - valid_loss: 0.2939 - valid_acc: 93.4445
# val_acc did not improve from 94.2222
# Epoch: 095 - train_loss: 0.0026 - train_acc: 100.0000 - valid_loss: 0.2917 - valid_acc: 93.3333
# val_acc did not improve from 94.2222
# Epoch: 096 - train_loss: 0.0027 - train_acc: 100.0000 - valid_loss: 0.2757 - valid_acc: 93.7778
# val_acc did not improve from 94.2222
# Epoch: 097 - train_loss: 0.0047 - train_acc: 100.0000 - valid_loss: 0.2781 - valid_acc: 93.5556
# val_acc did not improve from 94.2222
# Epoch: 098 - train_loss: 0.0068 - train_acc: 99.5556 - valid_loss: 0.2804 - valid_acc: 93.6667
# val_acc did not improve from 94.2222
# Epoch: 099 - train_loss: 0.0180 - train_acc: 99.5556 - valid_loss: 0.2884 - valid_acc: 93.0000
# val_acc did not improve from 94.2222
# Epoch: 100 - train_loss: 0.0037 - train_acc: 100.0000 - valid_loss: 0.4439 - valid_acc: 90.7778
# val_acc did not improve from 94.2222
# Running Time: 28.25
# **************************************************

# %%
model.load_state_dict(torch.load(path))
model.eval()

tar_test, pre_test = test(model, test_loader)
OA_test, AA_mean_test, Kappa_test, AA_test = output_metric(tar_test, pre_test)
AA_test = np.around(AA_test*100, 2)

# %%
print("*******************************************************************")
print("Final result:")
print("OA: {:.2f}, AA: {:.2f}, Kappa: {:.4f}".format(OA_test * 100., AA_mean_test*100., Kappa_test))
print("*******************************************************************")
print("Recal: {}".format(AA_test))
print("*******************************************************************")
print("Parameter:")
print_args(vars(args))
print("*******************************************************************")
# Out:
# *******************************************************************
# Final result:
# OA: 94.81, AA: 94.13, Kappa: 0.9317
# *******************************************************************
# Recal: [ 92.16  95.5   86.89  91.74  99.7   98.62 100.    96.53  86.01]
# *******************************************************************
# Parameter:
# dataset: Pavia
# seed: 42
# batch_size: 30
# patch_size: 15
# epoches: 100
# learning_rate: 0.001
# gamma: 0.99
# weight_decay: 0.001
# train_number: 25
# *******************************************************************

# %%
average_accuracy = str(list(AA_test))
file_name = "./CR/gaht_1.txt"

with open(file_name, 'w') as x_file:
    x_file.write("[{:.2f}, {:.2f}, {:.4f}]".format(OA_test * 100., AA_mean_test*100., Kappa_test))
    x_file.write('\n')
    x_file.write('{}'.format(average_accuracy))

# %% [markdown]
# ## Panoramic Classification

# %%
def output_label(model, loader):
    model.eval()
    pre = np.array([]).astype('int')
    with torch.no_grad():
        for batch_idx, (batch_data, batch_target) in enumerate(loader):
            batch_data = batch_data.cuda()
            batch_pred = model(batch_data)  # (B, 9)
            _, pred = batch_pred.topk(1, axis=1)  # (B, 1)
            pp = pred.squeeze()
            pre = np.append(pre, pp.data.cpu().numpy())
    return pre

# %%
pos_forward, pos_backward = choose_all_pixels(label)

x_forward, x_backward, y_forward, y_backward = all_data(mirror_data, band, pos_forward, pos_backward, patch_size=args.patch_size)
# Out:
# *******************************************************
# x_forward shape = (42776, 15, 15, 30), type = float64
# x_backward  shape = (164624, 15, 15, 30), type = float64
# *******************************************************

# %%
# load data
x_forward = torch.from_numpy(x_forward.transpose(0, 3, 1, 2)).type(torch.FloatTensor)
print(x_forward.shape)
y_forward = torch.from_numpy(y_forward).type(torch.LongTensor)  # (13,)
forward_label = Data.TensorDataset(x_forward, y_forward)

x_backward = torch.from_numpy(x_backward.transpose(0, 3, 1, 2)).type(torch.FloatTensor)
print(x_backward.shape)
y_backward = torch.from_numpy(y_backward).type(torch.LongTensor)  # (13,)
backward_label = Data.TensorDataset(x_backward, y_backward)

forward_loader = Data.DataLoader(forward_label, batch_size=128, shuffle=False)
backward_loader = Data.DataLoader(backward_label, batch_size=128, shuffle=False)
# Out:
# torch.Size([42776, 30, 15, 15])
# torch.Size([164624, 30, 15, 15])

# %%
# output classification maps
pre_forward = output_label(model, forward_loader)
pre_backward = output_label(model, backward_loader)

prediction_matrix = np.zeros((height, width), dtype=float)  # (512, 614)
for i in range(pos_forward.shape[0]):
    prediction_matrix[pos_forward[i, 0], pos_forward[i, 1]] = pre_forward[i] + 1

for j in range(pos_backward.shape[0]):
    prediction_matrix[pos_backward[j, 0], pos_backward[j, 1]] = pre_backward[j] + 1

# %%
predict_map = list_to_colormap(prediction_matrix.ravel())
predict_map = np.reshape(predict_map, (height, width, 3))

classification_map(predict_map, './pu_gaht.pdf')
