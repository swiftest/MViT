# %%
import os
import time
import math
import argparse
import numpy as np
import scipy.io as sio
import matplotlib as mpl
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler


import torch
import torch.nn as nn
from torch import optim
import torch.utils.data as Data
import torch.nn.functional as F
from torchsummary import summary
from einops import rearrange, repeat
from timm.models.vision_transformer import Block


from data_prepare import mirror_hsi
from data_prepare import choose_train_and_test
from data_prepare import choose_all_pixels, all_data
from data_prepare import train_and_test_data, train_and_test_label


from hybridformer import ViT
from CNNUtils import train, test, valid
from Utils import output_metric, plot_confusion_matrix
from Utils import list_to_colormap, classification_map, print_args


# %matplotlib inline

# %%
parser = argparse.ArgumentParser("HybridFormer")
parser.add_argument('--dataset', choices=['LongKou', 'HanChuan', 'HongHu', 'Pavia'], default='Pavia', help='dataset to use')
parser.add_argument('--seed', type=int, default=42, help='number of seed')
parser.add_argument('--batch_size', type=int, default=30, help='number of batch size')
parser.add_argument('--patch_size', type=int, default=15, help='size of patches')
parser.add_argument('--epoches', type=int, default=100, help='epoch number')
parser.add_argument('--learning_rate', type=float, default=1e-3, help='learning rate')
parser.add_argument('--gamma', type=float, default=0.99, help='gamma')
parser.add_argument('--weight_decay', type=float, default=0.001, help='weight_decay')
parser.add_argument('--train_number', type=int, default=25, help='num_train_per_class')
args = parser.parse_args(args=[])

# %%
# prepare data
data_path = os.path.join(os.getcwd(), 'dataset')

if args.dataset == 'LongKou':
    data = sio.loadmat(os.path.join(data_path, 'WHU_Hi_LongKou.mat'))['WHU_Hi_LongKou']
    label = sio.loadmat(os.path.join(data_path, 'WHU_Hi_LongKou_gt.mat'))['WHU_Hi_LongKou_gt']
elif args.dataset == 'HanChuan':
    data = sio.loadmat(os.path.join(data_path, 'WHU_Hi_HanChuan.mat'))['WHU_Hi_HanChuan']
    label = sio.loadmat(os.path.join(data_path, 'WHU_Hi_HanChuan_gt.mat'))['WHU_Hi_HanChuan_gt']
elif args.dataset == 'HongHu':
    data = sio.loadmat(os.path.join(data_path, 'WHU_Hi_HongHu.mat'))['WHU_Hi_HongHu']
    label = sio.loadmat(os.path.join(data_path, 'WHU_Hi_HongHu_gt.mat'))['WHU_Hi_HongHu_gt']
elif args.dataset == 'Pavia':
    data = sio.loadmat(os.path.join(data_path, 'PaviaU.mat'))['paviaU']
    label = sio.loadmat(os.path.join(data_path, 'PaviaU_gt.mat'))['paviaU_gt']
else:
    raise ValueError("Unknown dataset")
    
num_classes = np.max(label)
print('The class numbers of the HSI data is:', num_classes)
# Out:
# The class numbers of the HSI data is: 9

# %%
shapeor = data.shape
data = data.reshape(np.prod(data.shape[:2]), np.prod(data.shape[2:]))

std_scaler = StandardScaler()
std_data = std_scaler.fit_transform(data)
data = std_data.reshape(shapeor)

# %%
def applyPCA(data, numComponents=30):
    new_data = np.reshape(data, (-1, data.shape[2]))
    pca = PCA(n_components=numComponents, whiten=True)
    new_data = pca.fit_transform(new_data)
    new_data = np.reshape(new_data, (data.shape[0], data.shape[1], numComponents))
    return new_data, pca

# %%
K = 30
data, pca = applyPCA(data, numComponents=K)

# data size
height, width, band = data.shape
print("height={0}, width={1}, band={2}".format(height, width, band))
# Out:
# height=610, width=340, band=30

# %%
mirror_data = mirror_hsi(height, width, band, data, patch_size=args.patch_size)
# Out:
# *******************************************************
# patch_size : 15
# mirror_data shape : [624, 354, 30]
# *******************************************************

# %%
total_pos_train, total_pos_test, total_pos_valid, number_train, number_test, number_valid = choose_train_and_test(label, args.train_number, args.seed) 

x_train, x_test, x_valid = train_and_test_data(mirror_data, band, total_pos_train, total_pos_test, total_pos_valid, args.patch_size)
y_train, y_test, y_valid = train_and_test_label(number_train, number_test, number_valid, num_classes)
# Out:
# *******************************************************
# x_train shape = (225, 15, 15, 30), type = float64
# x_test  shape = (42551, 15, 15, 30), type = float64
# x_valid  shape = (900, 15, 15, 30), type = float64
# *******************************************************
# y_train: shape = (225,), type = int64
# y_test: shape = (42551,), type = int64
# y_valid: shape = (900,), type = int64
# *******************************************************

# %%
total_pos_train[:10]
# Out:
# array([[409, 293],
#        [404, 298],
#        [380, 301],
#        [551,  14],
#        [453, 165],
#        [140, 172],
#        [471, 169],
#        [175, 187],
#        [482, 185],
#        [214, 200]])

# %%
# load data
x_train = torch.from_numpy(x_train.transpose(0, 3, 1, 2)).type(torch.FloatTensor)  # (90, 30, 15, 15)
print(x_train.shape)
y_train = torch.from_numpy(y_train).type(torch.LongTensor)  # (13,)
train_label = Data.TensorDataset(x_train, y_train)

x_test = torch.from_numpy(x_test.transpose(0, 3, 1, 2)).type(torch.FloatTensor)  # (5198, 30, 15, 15)
print(x_test.shape)
y_test = torch.from_numpy(y_test).type(torch.LongTensor)  # (5198,)
test_label = Data.TensorDataset(x_test, y_test)

x_valid = torch.from_numpy(x_valid.transpose(0, 3, 1, 2)).type(torch.FloatTensor)  # (5211, 30, 15, 15)
print(x_valid.shape)
y_valid = torch.from_numpy(y_valid).type(torch.LongTensor)
valid_label = Data.TensorDataset(x_valid, y_valid)

train_loader = Data.DataLoader(train_label, batch_size=30, shuffle=True)
test_loader = Data.DataLoader(test_label, batch_size=128, shuffle=True)
valid_loader = Data.DataLoader(valid_label, batch_size=64, shuffle=True)
# Out:
# torch.Size([225, 30, 15, 15])
# torch.Size([42551, 30, 15, 15])
# torch.Size([900, 30, 15, 15])

# %% [markdown]
# ## Model

# %%
model = ViT(image_size=args.patch_size, patch_size=[3, 5], num_classes=num_classes, dim=64, depth=4, 
            heads=4, mlp_dim=512, channels=band, dropout=0.2, emb_dropout=0.2).cuda()

criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=1e-3, betas=(0.9, 0.999), eps=1e-8, weight_decay=0)
scheduler = optim.lr_scheduler.ExponentialLR(optimizer, gamma=args.gamma)

# %%
def model_summary(model):
    total_param = 0
    for name, param in model.named_parameters():
        if param.requires_grad:
            num_param = np.prod(param.size())
            if param.dim() > 1:
                print(name+':', 'x'.join(str(x) for x in list(param.size())), '=', num_param)
            else:
                print(name+':', num_param)
            total_param += num_param
    print("\nTotal Trainable Parameters:", total_param)

# %% [raw]
# model_summary(model)

# %%
print('start training')
acc_list = [0.00]
path = './model/hybridformer.pt'
tic = time.time()
for epoch in range(args.epoches):
    # 计算的是移动平均准确率
    train_acc, train_loss = train(model, train_loader, criterion, optimizer)
    valid_acc, valid_loss = valid(model, valid_loader, criterion)
    print("Epoch: {:03d} - train_loss: {:.4f} - train_acc: {:.4f} - valid_loss: {:.4f} - valid_acc: {:.4f}".\
          format(epoch+1, train_loss, train_acc, valid_loss, valid_acc))
    scheduler.step()

    acc_list.append(valid_acc)
    if acc_list[-1] > acc_list[-2]:
        print("val_acc improved from {:.4f} to {:.4f}, saving model to hybridformer.pt".format(acc_list[-2], acc_list[-1]))
        torch.save(model.state_dict(), path)
    else:
        print("val_acc did not improve from {:.4f}".format(acc_list[-2]))
        acc_list[-1] = acc_list[-2]

toc = time.time()
print("Running Time: {:.2f}".format(toc-tic))
print("**************************************************")
# Out:
# start training
# Epoch: 001 - train_loss: 1.9043 - train_acc: 29.7778 - valid_loss: 1.7846 - valid_acc: 37.1111
# val_acc improved from 0.0000 to 37.1111, saving model to hybridformer.pt
# Epoch: 002 - train_loss: 0.8547 - train_acc: 71.1111 - valid_loss: 0.8251 - valid_acc: 71.2222
# val_acc improved from 37.1111 to 71.2222, saving model to hybridformer.pt
# Epoch: 003 - train_loss: 0.4262 - train_acc: 84.0000 - valid_loss: 0.4109 - valid_acc: 86.6667
# val_acc improved from 71.2222 to 86.6667, saving model to hybridformer.pt
# Epoch: 004 - train_loss: 0.2617 - train_acc: 91.1111 - valid_loss: 0.3383 - valid_acc: 87.7778
# val_acc improved from 86.6667 to 87.7778, saving model to hybridformer.pt
# Epoch: 005 - train_loss: 0.1598 - train_acc: 96.0000 - valid_loss: 0.2519 - valid_acc: 90.7778
# val_acc improved from 87.7778 to 90.7778, saving model to hybridformer.pt
# Epoch: 006 - train_loss: 0.1737 - train_acc: 94.2222 - valid_loss: 0.2600 - valid_acc: 91.0000
# val_acc improved from 90.7778 to 91.0000, saving model to hybridformer.pt
# Epoch: 007 - train_loss: 0.1085 - train_acc: 98.2222 - valid_loss: 0.3270 - valid_acc: 87.6667
# val_acc did not improve from 91.0000
# Epoch: 008 - train_loss: 0.1622 - train_acc: 96.0000 - valid_loss: 0.2955 - valid_acc: 90.6667
# val_acc did not improve from 91.0000
# Epoch: 009 - train_loss: 0.1127 - train_acc: 96.4445 - valid_loss: 0.2942 - valid_acc: 91.0000
# val_acc did not improve from 91.0000
# Epoch: 010 - train_loss: 0.0538 - train_acc: 97.7778 - valid_loss: 0.3472 - valid_acc: 89.2222
# val_acc did not improve from 91.0000
# Epoch: 011 - train_loss: 0.0506 - train_acc: 97.7778 - valid_loss: 0.3773 - valid_acc: 89.0000
# val_acc did not improve from 91.0000
# Epoch: 012 - train_loss: 0.0299 - train_acc: 99.5556 - valid_loss: 0.3064 - valid_acc: 91.3333
# val_acc improved from 91.0000 to 91.3333, saving model to hybridformer.pt
# Epoch: 013 - train_loss: 0.0242 - train_acc: 100.0000 - valid_loss: 0.2323 - valid_acc: 92.5556
# val_acc improved from 91.3333 to 92.5556, saving model to hybridformer.pt
# Epoch: 014 - train_loss: 0.0184 - train_acc: 100.0000 - valid_loss: 0.2415 - valid_acc: 92.4445
# val_acc did not improve from 92.5556
# Epoch: 015 - train_loss: 0.0081 - train_acc: 100.0000 - valid_loss: 0.2599 - valid_acc: 92.1111
# val_acc did not improve from 92.5556
# Epoch: 016 - train_loss: 0.0062 - train_acc: 100.0000 - valid_loss: 0.2779 - valid_acc: 91.6667
# val_acc did not improve from 92.5556
# Epoch: 017 - train_loss: 0.0048 - train_acc: 100.0000 - valid_loss: 0.2679 - valid_acc: 92.0000
# val_acc did not improve from 92.5556
# Epoch: 018 - train_loss: 0.0047 - train_acc: 100.0000 - valid_loss: 0.2582 - valid_acc: 92.1111
# val_acc did not improve from 92.5556
# Epoch: 019 - train_loss: 0.0041 - train_acc: 100.0000 - valid_loss: 0.2506 - valid_acc: 92.4445
# val_acc did not improve from 92.5556
# Epoch: 020 - train_loss: 0.0049 - train_acc: 100.0000 - valid_loss: 0.2415 - valid_acc: 92.7778
# val_acc improved from 92.5556 to 92.7778, saving model to hybridformer.pt
# Epoch: 021 - train_loss: 0.0040 - train_acc: 100.0000 - valid_loss: 0.2332 - valid_acc: 92.7778
# val_acc did not improve from 92.7778
# Epoch: 022 - train_loss: 0.0034 - train_acc: 100.0000 - valid_loss: 0.2311 - valid_acc: 92.6667
# val_acc did not improve from 92.7778
# Epoch: 023 - train_loss: 0.0029 - train_acc: 100.0000 - valid_loss: 0.2323 - valid_acc: 93.0000
# val_acc improved from 92.7778 to 93.0000, saving model to hybridformer.pt
# Epoch: 024 - train_loss: 0.0023 - train_acc: 100.0000 - valid_loss: 0.2443 - valid_acc: 92.7778
# val_acc did not improve from 93.0000
# Epoch: 025 - train_loss: 0.0027 - train_acc: 100.0000 - valid_loss: 0.2361 - valid_acc: 92.7778
# val_acc did not improve from 93.0000
# Epoch: 026 - train_loss: 0.0023 - train_acc: 100.0000 - valid_loss: 0.2392 - valid_acc: 92.7778
# val_acc did not improve from 93.0000
# Epoch: 027 - train_loss: 0.0031 - train_acc: 100.0000 - valid_loss: 0.2342 - valid_acc: 93.0000
# val_acc did not improve from 93.0000
# Epoch: 028 - train_loss: 0.0034 - train_acc: 100.0000 - valid_loss: 0.2491 - valid_acc: 93.0000
# val_acc did not improve from 93.0000
# Epoch: 029 - train_loss: 0.0019 - train_acc: 100.0000 - valid_loss: 0.2560 - valid_acc: 92.8889
# val_acc did not improve from 93.0000
# Epoch: 030 - train_loss: 0.0027 - train_acc: 100.0000 - valid_loss: 0.2557 - valid_acc: 92.6667
# val_acc did not improve from 93.0000
# Epoch: 031 - train_loss: 0.0022 - train_acc: 100.0000 - valid_loss: 0.2528 - valid_acc: 92.7778
# val_acc did not improve from 93.0000
# Epoch: 032 - train_loss: 0.0031 - train_acc: 100.0000 - valid_loss: 0.2610 - valid_acc: 92.5556
# val_acc did not improve from 93.0000
# Epoch: 033 - train_loss: 0.0029 - train_acc: 100.0000 - valid_loss: 0.2580 - valid_acc: 92.6667
# val_acc did not improve from 93.0000
# Epoch: 034 - train_loss: 0.0027 - train_acc: 100.0000 - valid_loss: 0.2378 - valid_acc: 93.1111
# val_acc improved from 93.0000 to 93.1111, saving model to hybridformer.pt
# Epoch: 035 - train_loss: 0.0018 - train_acc: 100.0000 - valid_loss: 0.2466 - valid_acc: 93.1111
# val_acc did not improve from 93.1111
# Epoch: 036 - train_loss: 0.0020 - train_acc: 100.0000 - valid_loss: 0.2467 - valid_acc: 93.1111
# val_acc did not improve from 93.1111
# Epoch: 037 - train_loss: 0.0015 - train_acc: 100.0000 - valid_loss: 0.2516 - valid_acc: 93.2222
# val_acc improved from 93.1111 to 93.2222, saving model to hybridformer.pt
# Epoch: 038 - train_loss: 0.0017 - train_acc: 100.0000 - valid_loss: 0.2566 - valid_acc: 92.6667
# val_acc did not improve from 93.2222
# Epoch: 039 - train_loss: 0.0016 - train_acc: 100.0000 - valid_loss: 0.2523 - valid_acc: 92.8889
# val_acc did not improve from 93.2222
# Epoch: 040 - train_loss: 0.0010 - train_acc: 100.0000 - valid_loss: 0.2496 - valid_acc: 92.7778
# val_acc did not improve from 93.2222
# Epoch: 041 - train_loss: 0.0011 - train_acc: 100.0000 - valid_loss: 0.2525 - valid_acc: 92.7778
# val_acc did not improve from 93.2222
# Epoch: 042 - train_loss: 0.0011 - train_acc: 100.0000 - valid_loss: 0.2390 - valid_acc: 92.8889
# val_acc did not improve from 93.2222
# Epoch: 043 - train_loss: 0.0014 - train_acc: 100.0000 - valid_loss: 0.2464 - valid_acc: 93.0000
# val_acc did not improve from 93.2222
# Epoch: 044 - train_loss: 0.0012 - train_acc: 100.0000 - valid_loss: 0.2486 - valid_acc: 92.8889
# val_acc did not improve from 93.2222
# Epoch: 045 - train_loss: 0.0008 - train_acc: 100.0000 - valid_loss: 0.2468 - valid_acc: 92.8889
# val_acc did not improve from 93.2222
# Epoch: 046 - train_loss: 0.0008 - train_acc: 100.0000 - valid_loss: 0.2450 - valid_acc: 93.0000
# val_acc did not improve from 93.2222
# Epoch: 047 - train_loss: 0.0010 - train_acc: 100.0000 - valid_loss: 0.2469 - valid_acc: 93.0000
# val_acc did not improve from 93.2222
# Epoch: 048 - train_loss: 0.0013 - train_acc: 100.0000 - valid_loss: 0.2516 - valid_acc: 93.0000
# val_acc did not improve from 93.2222
# Epoch: 049 - train_loss: 0.0009 - train_acc: 100.0000 - valid_loss: 0.2426 - valid_acc: 93.3333
# val_acc improved from 93.2222 to 93.3333, saving model to hybridformer.pt
# Epoch: 050 - train_loss: 0.0010 - train_acc: 100.0000 - valid_loss: 0.2382 - valid_acc: 93.4445
# val_acc improved from 93.3333 to 93.4445, saving model to hybridformer.pt
# Epoch: 051 - train_loss: 0.0012 - train_acc: 100.0000 - valid_loss: 0.2370 - valid_acc: 93.3333
# val_acc did not improve from 93.4445
# Epoch: 052 - train_loss: 0.0008 - train_acc: 100.0000 - valid_loss: 0.2390 - valid_acc: 93.4445
# val_acc did not improve from 93.4445
# Epoch: 053 - train_loss: 0.0015 - train_acc: 100.0000 - valid_loss: 0.2404 - valid_acc: 93.3333
# val_acc did not improve from 93.4445
# Epoch: 054 - train_loss: 0.0006 - train_acc: 100.0000 - valid_loss: 0.2479 - valid_acc: 93.1111
# val_acc did not improve from 93.4445
# Epoch: 055 - train_loss: 0.0009 - train_acc: 100.0000 - valid_loss: 0.2547 - valid_acc: 93.1111
# val_acc did not improve from 93.4445
# Epoch: 056 - train_loss: 0.0014 - train_acc: 100.0000 - valid_loss: 0.2476 - valid_acc: 93.1111
# val_acc did not improve from 93.4445
# Epoch: 057 - train_loss: 0.0009 - train_acc: 100.0000 - valid_loss: 0.2554 - valid_acc: 92.7778
# val_acc did not improve from 93.4445
# Epoch: 058 - train_loss: 0.0007 - train_acc: 100.0000 - valid_loss: 0.2587 - valid_acc: 92.7778
# val_acc did not improve from 93.4445
# Epoch: 059 - train_loss: 0.0012 - train_acc: 100.0000 - valid_loss: 0.2503 - valid_acc: 92.8889
# val_acc did not improve from 93.4445
# Epoch: 060 - train_loss: 0.0010 - train_acc: 100.0000 - valid_loss: 0.2454 - valid_acc: 93.1111
# val_acc did not improve from 93.4445
# Epoch: 061 - train_loss: 0.0005 - train_acc: 100.0000 - valid_loss: 0.2436 - valid_acc: 93.2222
# val_acc did not improve from 93.4445
# Epoch: 062 - train_loss: 0.0010 - train_acc: 100.0000 - valid_loss: 0.2357 - valid_acc: 93.2222
# val_acc did not improve from 93.4445
# Epoch: 063 - train_loss: 0.0149 - train_acc: 99.1111 - valid_loss: 0.3319 - valid_acc: 91.2222
# val_acc did not improve from 93.4445
# Epoch: 064 - train_loss: 0.0495 - train_acc: 97.7778 - valid_loss: 0.2750 - valid_acc: 92.2222
# val_acc did not improve from 93.4445
# Epoch: 065 - train_loss: 0.0276 - train_acc: 99.1111 - valid_loss: 0.2503 - valid_acc: 93.1111
# val_acc did not improve from 93.4445
# Epoch: 066 - train_loss: 0.0092 - train_acc: 100.0000 - valid_loss: 0.2466 - valid_acc: 92.7778
# val_acc did not improve from 93.4445
# Epoch: 067 - train_loss: 0.0092 - train_acc: 99.5556 - valid_loss: 0.3076 - valid_acc: 91.7778
# val_acc did not improve from 93.4445
# Epoch: 068 - train_loss: 0.0117 - train_acc: 100.0000 - valid_loss: 0.2851 - valid_acc: 91.8889
# val_acc did not improve from 93.4445
# Epoch: 069 - train_loss: 0.0046 - train_acc: 100.0000 - valid_loss: 0.2625 - valid_acc: 92.0000
# val_acc did not improve from 93.4445
# Epoch: 070 - train_loss: 0.0071 - train_acc: 100.0000 - valid_loss: 0.2516 - valid_acc: 92.7778
# val_acc did not improve from 93.4445
# Epoch: 071 - train_loss: 0.0031 - train_acc: 100.0000 - valid_loss: 0.2576 - valid_acc: 93.0000
# val_acc did not improve from 93.4445
# Epoch: 072 - train_loss: 0.0019 - train_acc: 100.0000 - valid_loss: 0.2685 - valid_acc: 92.8889
# val_acc did not improve from 93.4445
# Epoch: 073 - train_loss: 0.0017 - train_acc: 100.0000 - valid_loss: 0.2717 - valid_acc: 92.6667
# val_acc did not improve from 93.4445
# Epoch: 074 - train_loss: 0.0020 - train_acc: 100.0000 - valid_loss: 0.2714 - valid_acc: 93.0000
# val_acc did not improve from 93.4445
# Epoch: 075 - train_loss: 0.0008 - train_acc: 100.0000 - valid_loss: 0.2743 - valid_acc: 93.0000
# val_acc did not improve from 93.4445
# Epoch: 076 - train_loss: 0.0013 - train_acc: 100.0000 - valid_loss: 0.2770 - valid_acc: 92.7778
# val_acc did not improve from 93.4445
# Epoch: 077 - train_loss: 0.0010 - train_acc: 100.0000 - valid_loss: 0.2800 - valid_acc: 92.7778
# val_acc did not improve from 93.4445
# Epoch: 078 - train_loss: 0.0009 - train_acc: 100.0000 - valid_loss: 0.2799 - valid_acc: 92.6667
# val_acc did not improve from 93.4445
# Epoch: 079 - train_loss: 0.0013 - train_acc: 100.0000 - valid_loss: 0.2950 - valid_acc: 92.3333
# val_acc did not improve from 93.4445
# Epoch: 080 - train_loss: 0.0006 - train_acc: 100.0000 - valid_loss: 0.3107 - valid_acc: 91.7778
# val_acc did not improve from 93.4445
# Epoch: 081 - train_loss: 0.0009 - train_acc: 100.0000 - valid_loss: 0.3106 - valid_acc: 91.7778
# val_acc did not improve from 93.4445
# Epoch: 082 - train_loss: 0.0005 - train_acc: 100.0000 - valid_loss: 0.3166 - valid_acc: 91.7778
# val_acc did not improve from 93.4445
# Epoch: 083 - train_loss: 0.0009 - train_acc: 100.0000 - valid_loss: 0.3087 - valid_acc: 92.3333
# val_acc did not improve from 93.4445
# Epoch: 084 - train_loss: 0.0007 - train_acc: 100.0000 - valid_loss: 0.3072 - valid_acc: 92.4445
# val_acc did not improve from 93.4445
# Epoch: 085 - train_loss: 0.0006 - train_acc: 100.0000 - valid_loss: 0.3102 - valid_acc: 92.2222
# val_acc did not improve from 93.4445
# Epoch: 086 - train_loss: 0.0005 - train_acc: 100.0000 - valid_loss: 0.3110 - valid_acc: 92.2222
# val_acc did not improve from 93.4445
# Epoch: 087 - train_loss: 0.0006 - train_acc: 100.0000 - valid_loss: 0.2995 - valid_acc: 92.3333
# val_acc did not improve from 93.4445
# Epoch: 088 - train_loss: 0.0007 - train_acc: 100.0000 - valid_loss: 0.2941 - valid_acc: 92.6667
# val_acc did not improve from 93.4445
# Epoch: 089 - train_loss: 0.0007 - train_acc: 100.0000 - valid_loss: 0.3022 - valid_acc: 92.2222
# val_acc did not improve from 93.4445
# Epoch: 090 - train_loss: 0.0006 - train_acc: 100.0000 - valid_loss: 0.2937 - valid_acc: 92.6667
# val_acc did not improve from 93.4445
# Epoch: 091 - train_loss: 0.0005 - train_acc: 100.0000 - valid_loss: 0.2930 - valid_acc: 92.5556
# val_acc did not improve from 93.4445
# Epoch: 092 - train_loss: 0.0006 - train_acc: 100.0000 - valid_loss: 0.2922 - valid_acc: 92.8889
# val_acc did not improve from 93.4445
# Epoch: 093 - train_loss: 0.0006 - train_acc: 100.0000 - valid_loss: 0.3019 - valid_acc: 92.3333
# val_acc did not improve from 93.4445
# Epoch: 094 - train_loss: 0.0005 - train_acc: 100.0000 - valid_loss: 0.3030 - valid_acc: 92.3333
# val_acc did not improve from 93.4445
# Epoch: 095 - train_loss: 0.0004 - train_acc: 100.0000 - valid_loss: 0.3043 - valid_acc: 92.3333
# val_acc did not improve from 93.4445
# Epoch: 096 - train_loss: 0.0004 - train_acc: 100.0000 - valid_loss: 0.3049 - valid_acc: 92.3333
# val_acc did not improve from 93.4445
# Epoch: 097 - train_loss: 0.0006 - train_acc: 100.0000 - valid_loss: 0.2968 - valid_acc: 92.5556
# val_acc did not improve from 93.4445
# Epoch: 098 - train_loss: 0.0005 - train_acc: 100.0000 - valid_loss: 0.2940 - valid_acc: 92.6667
# val_acc did not improve from 93.4445
# Epoch: 099 - train_loss: 0.0003 - train_acc: 100.0000 - valid_loss: 0.2972 - valid_acc: 92.5556
# val_acc did not improve from 93.4445
# Epoch: 100 - train_loss: 0.0006 - train_acc: 100.0000 - valid_loss: 0.3022 - valid_acc: 92.3333
# val_acc did not improve from 93.4445
# Running Time: 46.37
# **************************************************

# %%
model.load_state_dict(torch.load(path))
model.eval()

tar_test, pre_test = test(model, test_loader)
OA_test, AA_mean_test, Kappa_test, AA_test = output_metric(tar_test, pre_test)
AA_test = np.around(AA_test*100, 2)

# %%
print("*******************************************************************")
print("Final result:")
print("OA: {:.2f}, AA: {:.2f}, Kappa: {:.4f}".format(OA_test * 100., AA_mean_test*100., Kappa_test))
print("*******************************************************************")
print("Recal: {}".format(AA_test))
print("*******************************************************************")
print("Parameter:")
print_args(vars(args))
print("*******************************************************************")
# Out:
# *******************************************************************
# Final result:
# OA: 93.93, AA: 94.22, Kappa: 0.9203
# *******************************************************************
# Recal: [ 91.3   94.9   83.03  96.25  99.85  99.58 100.    84.93  98.16]
# *******************************************************************
# Parameter:
# dataset: Pavia
# seed: 42
# batch_size: 30
# patch_size: 15
# epoches: 100
# learning_rate: 0.001
# gamma: 0.99
# weight_decay: 0.001
# train_number: 25
# *******************************************************************

# %%
average_accuracy = str(list(AA_test))
file_name = "./CR/hybridformer_1.txt"

with open(file_name, 'w') as x_file:
    x_file.write("[{:.2f}, {:.2f}, {:.4f}]".format(OA_test * 100., AA_mean_test*100., Kappa_test))
    x_file.write('\n')
    x_file.write('{}'.format(average_accuracy))

# %% [markdown]
# ## Panoramic Classification

# %%
def output_label(model, loader):
    model.eval()
    pre = np.array([]).astype('int')
    with torch.no_grad():
        for batch_idx, (batch_data, batch_target) in enumerate(loader):
            batch_data = batch_data.cuda()
            batch_pred = model(batch_data)  # (B, 9)
            _, pred = batch_pred.topk(1, axis=1)  # (B, 1)
            pp = pred.squeeze()
            pre = np.append(pre, pp.data.cpu().numpy())
    return pre

# %%
pos_forward, pos_backward = choose_all_pixels(label)

x_forward, x_backward, y_forward, y_backward = all_data(mirror_data, band, pos_forward, pos_backward, patch_size=args.patch_size)
# Out:
# *******************************************************
# x_forward shape = (42776, 15, 15, 30), type = float64
# x_backward  shape = (164624, 15, 15, 30), type = float64
# *******************************************************

# %%
# load data
x_forward = torch.from_numpy(x_forward.transpose(0, 3, 1, 2)).type(torch.FloatTensor)
print(x_forward.shape)
y_forward = torch.from_numpy(y_forward).type(torch.LongTensor)  # (13,)
forward_label = Data.TensorDataset(x_forward, y_forward)

x_backward = torch.from_numpy(x_backward.transpose(0, 3, 1, 2)).type(torch.FloatTensor)
print(x_backward.shape)
y_backward = torch.from_numpy(y_backward).type(torch.LongTensor)  # (13,)
backward_label = Data.TensorDataset(x_backward, y_backward)

forward_loader = Data.DataLoader(forward_label, batch_size=128, shuffle=False)
backward_loader = Data.DataLoader(backward_label, batch_size=128, shuffle=False)
# Out:
# torch.Size([42776, 30, 15, 15])
# torch.Size([164624, 30, 15, 15])

# %%
# output classification maps
pre_forward = output_label(model, forward_loader)
pre_backward = output_label(model, backward_loader)

prediction_matrix = np.zeros((height, width), dtype=float)  # (512, 614)
for i in range(pos_forward.shape[0]):
    prediction_matrix[pos_forward[i, 0], pos_forward[i, 1]] = pre_forward[i] + 1

for j in range(pos_backward.shape[0]):
    prediction_matrix[pos_backward[j, 0], pos_backward[j, 1]] = pre_backward[j] + 1

# %%
predict_map = list_to_colormap(prediction_matrix.ravel())
predict_map = np.reshape(predict_map, (height, width, 3))

classification_map(predict_map, './pu_hybridformer.pdf')
