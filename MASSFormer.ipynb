# %%
import os
import time
import random
import argparse
import numpy as np
import scipy.io as sio
import matplotlib as mpl
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler


import torch
import torch.nn as nn
import torch.optim as optim
import torch.utils.data as Data
import torch.backends.cudnn as cudnn


from data_prepare import mirror_hsi
from data_prepare import choose_train_and_test
from data_prepare import choose_all_pixels, all_data
from data_prepare import train_and_test_data, train_and_test_label


from massformer import Massformer
from CNNUtils import train, test, valid
from Utils import output_metric, plot_confusion_matrix
from Utils import list_to_colormap, classification_map, print_args


# %matplotlib inline

# %%
parser = argparse.ArgumentParser("SSFTTnet")
parser.add_argument('--dataset', choices=['LongKou', 'HanChuan', 'HongHu', 'Pavia'], default='Pavia', help='dataset to use')
parser.add_argument('--seed', type=int, default=42, help='number of seed')
parser.add_argument('--batch_size', type=int, default=30, help='number of batch size')
parser.add_argument('--patch_size', type=int, default=15, help='size of patches')
parser.add_argument('--epoches', type=int, default=100, help='epoch number')
parser.add_argument('--learning_rate', type=float, default=1e-3, help='learning rate')
parser.add_argument('--gamma', type=float, default=0.99, help='gamma')
parser.add_argument('--weight_decay', type=float, default=0.001, help='weight_decay')
parser.add_argument('--train_number', type=int, default=25, help='num_train_per_class')
args = parser.parse_args(args=[])

# %%
# prepare data
data_path = os.path.join(os.getcwd(), 'dataset')

if args.dataset == 'LongKou':
    data = sio.loadmat(os.path.join(data_path, 'WHU_Hi_LongKou.mat'))['WHU_Hi_LongKou']
    label = sio.loadmat(os.path.join(data_path, 'WHU_Hi_LongKou_gt.mat'))['WHU_Hi_LongKou_gt']
elif args.dataset == 'Pavia':
    data = sio.loadmat(os.path.join(data_path, 'PaviaU.mat'))['paviaU']
    label = sio.loadmat(os.path.join(data_path, 'PaviaU_gt.mat'))['paviaU_gt']
else:
    raise ValueError("Unknown dataset")
    
num_classes = np.max(label)
print('The class numbers of the HSI data is:', num_classes)
# Out:
# The class numbers of the HSI data is: 9

# %%
shapeor = data.shape
data = data.reshape(np.prod(data.shape[:2]), np.prod(data.shape[2:]))

std_scaler = StandardScaler()
std_data = std_scaler.fit_transform(data)
data = std_data.reshape(shapeor)

# %%
def applyPCA(data, numComponents=30):
    new_data = np.reshape(data, (-1, data.shape[2]))
    pca = PCA(n_components=numComponents, whiten=True)
    new_data = pca.fit_transform(new_data)
    new_data = np.reshape(new_data, (data.shape[0], data.shape[1], numComponents))
    return new_data, pca

# %%
K = 30
data, pca = applyPCA(data, numComponents=K)

# data size
height, width, band = data.shape
print("height={0}, width={1}, band={2}".format(height, width, band))
# Out:
# height=610, width=340, band=30

# %%
mirror_data = mirror_hsi(height, width, band, data, patch_size=args.patch_size)
# Out:
# *******************************************************
# patch_size : 15
# mirror_data shape : [624, 354, 30]
# *******************************************************

# %%
total_pos_train, total_pos_test, total_pos_valid, number_train, number_test, number_valid = choose_train_and_test(label, args.train_number, args.seed) 

x_train, x_test, x_valid = train_and_test_data(mirror_data, band, total_pos_train, total_pos_test, total_pos_valid, args.patch_size)
y_train, y_test, y_valid = train_and_test_label(number_train, number_test, number_valid, num_classes)
# Out:
# *******************************************************
# x_train shape = (225, 15, 15, 30), type = float64
# x_test  shape = (42551, 15, 15, 30), type = float64
# x_valid  shape = (900, 15, 15, 30), type = float64
# *******************************************************
# y_train: shape = (225,), type = int64
# y_test: shape = (42551,), type = int64
# y_valid: shape = (900,), type = int64
# *******************************************************

# %%
total_pos_train[:10]
# Out:
# array([[409, 293],
#        [404, 298],
#        [380, 301],
#        [551,  14],
#        [453, 165],
#        [140, 172],
#        [471, 169],
#        [175, 187],
#        [482, 185],
#        [214, 200]])

# %%
# load data
x_train = torch.from_numpy(x_train.transpose(0, 3, 1, 2)).unsqueeze(1).type(torch.FloatTensor)  # (90, 30, 15, 15)
print(x_train.shape)
y_train = torch.from_numpy(y_train).type(torch.LongTensor)  # (13,)
train_label = Data.TensorDataset(x_train, y_train)

x_test = torch.from_numpy(x_test.transpose(0, 3, 1, 2)).unsqueeze(1).type(torch.FloatTensor)  # (5198, 30, 15, 15)
print(x_test.shape)
y_test = torch.from_numpy(y_test).type(torch.LongTensor)  # (5198,)
test_label = Data.TensorDataset(x_test, y_test)

x_valid = torch.from_numpy(x_valid.transpose(0, 3, 1, 2)).unsqueeze(1).type(torch.FloatTensor)  # (5211, 30, 15, 15)
print(x_valid.shape)
y_valid = torch.from_numpy(y_valid).type(torch.LongTensor)
valid_label = Data.TensorDataset(x_valid, y_valid)

train_loader = Data.DataLoader(train_label, batch_size=30, shuffle=True)
test_loader = Data.DataLoader(test_label, batch_size=128, shuffle=True)
valid_loader = Data.DataLoader(valid_label, batch_size=64, shuffle=True)
# Out:
# torch.Size([225, 1, 30, 15, 15])
# torch.Size([42551, 1, 30, 15, 15])
# torch.Size([900, 1, 30, 15, 15])

# %% [markdown]
# ## Model

# %%
model = Massformer(num_classes=num_classes).cuda()

criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=1e-3, betas=(0.9, 0.999), eps=1e-8, weight_decay=1e-06)
scheduler = optim.lr_scheduler.ExponentialLR(optimizer, gamma=args.gamma)

# %%
def model_summary(model):
    total_param = 0
    for name, param in model.named_parameters():
        if param.requires_grad:
            num_param = np.prod(param.size())
            if param.dim() > 1:
                print(name+':', 'x'.join(str(x) for x in list(param.size())), '=', num_param)
            else:
                print(name+':', num_param)
            total_param += num_param
    print("\nTotal Trainable Parameters:", total_param)

# %% [raw]
# model_summary(model)

# %%
print('start training')
acc_list = [0.00]
path = './model/MASSFormer.pt'
tic = time.time()
for epoch in range(args.epoches):
    # 计算的是移动平均准确率
    train_acc, train_loss = train(model, train_loader, criterion, optimizer)
    valid_acc, valid_loss = valid(model, valid_loader, criterion)
    print("Epoch: {:03d} - train_loss: {:.4f} - train_acc: {:.4f} - valid_loss: {:.4f} - valid_acc: {:.4f}".\
          format(epoch+1, train_loss, train_acc, valid_loss, valid_acc))
    scheduler.step()

    acc_list.append(valid_acc)
    if acc_list[-1] > acc_list[-2]:
        print("val_acc improved from {:.4f} to {:.4f}, saving model to MASSFormer.pt".format(acc_list[-2], acc_list[-1]))
        torch.save(model.state_dict(), path)
    else:
        print("val_acc did not improve from {:.4f}".format(acc_list[-2]))
        acc_list[-1] = acc_list[-2]

toc = time.time()
print("Running Time: {:.2f}".format(toc-tic))
print("**************************************************")
# Out:
# start training
# Epoch: 001 - train_loss: 1.8426 - train_acc: 34.2222 - valid_loss: 1.4112 - valid_acc: 45.1111
# val_acc improved from 0.0000 to 45.1111, saving model to MASSFormer.pt
# Epoch: 002 - train_loss: 1.0739 - train_acc: 64.8889 - valid_loss: 0.7998 - valid_acc: 74.4444
# val_acc improved from 45.1111 to 74.4444, saving model to MASSFormer.pt
# Epoch: 003 - train_loss: 0.7169 - train_acc: 81.3333 - valid_loss: 0.5864 - valid_acc: 83.0000
# val_acc improved from 74.4444 to 83.0000, saving model to MASSFormer.pt
# Epoch: 004 - train_loss: 0.5540 - train_acc: 82.2222 - valid_loss: 0.5765 - valid_acc: 84.5556
# val_acc improved from 83.0000 to 84.5556, saving model to MASSFormer.pt
# Epoch: 005 - train_loss: 0.4517 - train_acc: 86.6667 - valid_loss: 0.3794 - valid_acc: 88.2222
# val_acc improved from 84.5556 to 88.2222, saving model to MASSFormer.pt
# Epoch: 006 - train_loss: 0.3115 - train_acc: 92.4445 - valid_loss: 0.3146 - valid_acc: 91.2222
# val_acc improved from 88.2222 to 91.2222, saving model to MASSFormer.pt
# Epoch: 007 - train_loss: 0.2386 - train_acc: 93.7778 - valid_loss: 0.2594 - valid_acc: 92.8889
# val_acc improved from 91.2222 to 92.8889, saving model to MASSFormer.pt
# Epoch: 008 - train_loss: 0.1617 - train_acc: 96.8889 - valid_loss: 0.1958 - valid_acc: 94.5556
# val_acc improved from 92.8889 to 94.5556, saving model to MASSFormer.pt
# Epoch: 009 - train_loss: 0.1289 - train_acc: 98.6667 - valid_loss: 0.2643 - valid_acc: 91.5556
# val_acc did not improve from 94.5556
# Epoch: 010 - train_loss: 0.1166 - train_acc: 97.3333 - valid_loss: 0.1637 - valid_acc: 94.7778
# val_acc improved from 94.5556 to 94.7778, saving model to MASSFormer.pt
# Epoch: 011 - train_loss: 0.0822 - train_acc: 98.6667 - valid_loss: 0.2397 - valid_acc: 93.6667
# val_acc did not improve from 94.7778
# Epoch: 012 - train_loss: 0.1099 - train_acc: 98.6667 - valid_loss: 0.1744 - valid_acc: 94.7778
# val_acc did not improve from 94.7778
# Epoch: 013 - train_loss: 0.0612 - train_acc: 99.5556 - valid_loss: 0.1969 - valid_acc: 94.0000
# val_acc did not improve from 94.7778
# Epoch: 014 - train_loss: 0.0434 - train_acc: 100.0000 - valid_loss: 0.1358 - valid_acc: 96.1111
# val_acc improved from 94.7778 to 96.1111, saving model to MASSFormer.pt
# Epoch: 015 - train_loss: 0.0391 - train_acc: 100.0000 - valid_loss: 0.1786 - valid_acc: 95.1111
# val_acc did not improve from 96.1111
# Epoch: 016 - train_loss: 0.0320 - train_acc: 100.0000 - valid_loss: 0.1416 - valid_acc: 95.1111
# val_acc did not improve from 96.1111
# Epoch: 017 - train_loss: 0.0299 - train_acc: 100.0000 - valid_loss: 0.1721 - valid_acc: 94.7778
# val_acc did not improve from 96.1111
# Epoch: 018 - train_loss: 0.0271 - train_acc: 100.0000 - valid_loss: 0.1569 - valid_acc: 95.0000
# val_acc did not improve from 96.1111
# Epoch: 019 - train_loss: 0.0229 - train_acc: 100.0000 - valid_loss: 0.1236 - valid_acc: 95.8889
# val_acc did not improve from 96.1111
# Epoch: 020 - train_loss: 0.0198 - train_acc: 100.0000 - valid_loss: 0.1616 - valid_acc: 95.1111
# val_acc did not improve from 96.1111
# Epoch: 021 - train_loss: 0.0182 - train_acc: 100.0000 - valid_loss: 0.1724 - valid_acc: 95.1111
# val_acc did not improve from 96.1111
# Epoch: 022 - train_loss: 0.0170 - train_acc: 100.0000 - valid_loss: 0.1584 - valid_acc: 95.2222
# val_acc did not improve from 96.1111
# Epoch: 023 - train_loss: 0.0158 - train_acc: 100.0000 - valid_loss: 0.1389 - valid_acc: 95.2222
# val_acc did not improve from 96.1111
# Epoch: 024 - train_loss: 0.0146 - train_acc: 100.0000 - valid_loss: 0.1375 - valid_acc: 95.1111
# val_acc did not improve from 96.1111
# Epoch: 025 - train_loss: 0.0142 - train_acc: 100.0000 - valid_loss: 0.1457 - valid_acc: 95.3333
# val_acc did not improve from 96.1111
# Epoch: 026 - train_loss: 0.0133 - train_acc: 100.0000 - valid_loss: 0.1450 - valid_acc: 95.3333
# val_acc did not improve from 96.1111
# Epoch: 027 - train_loss: 0.0128 - train_acc: 100.0000 - valid_loss: 0.1247 - valid_acc: 95.6667
# val_acc did not improve from 96.1111
# Epoch: 028 - train_loss: 0.0123 - train_acc: 100.0000 - valid_loss: 0.1370 - valid_acc: 95.0000
# val_acc did not improve from 96.1111
# Epoch: 029 - train_loss: 0.0115 - train_acc: 100.0000 - valid_loss: 0.1341 - valid_acc: 95.1111
# val_acc did not improve from 96.1111
# Epoch: 030 - train_loss: 0.0110 - train_acc: 100.0000 - valid_loss: 0.1344 - valid_acc: 95.3333
# val_acc did not improve from 96.1111
# Epoch: 031 - train_loss: 0.0102 - train_acc: 100.0000 - valid_loss: 0.1306 - valid_acc: 95.3333
# val_acc did not improve from 96.1111
# Epoch: 032 - train_loss: 0.0101 - train_acc: 100.0000 - valid_loss: 0.1319 - valid_acc: 95.2222
# val_acc did not improve from 96.1111
# Epoch: 033 - train_loss: 0.0098 - train_acc: 100.0000 - valid_loss: 0.1372 - valid_acc: 95.4445
# val_acc did not improve from 96.1111
# Epoch: 034 - train_loss: 0.0095 - train_acc: 100.0000 - valid_loss: 0.1358 - valid_acc: 95.5556
# val_acc did not improve from 96.1111
# Epoch: 035 - train_loss: 0.0091 - train_acc: 100.0000 - valid_loss: 0.1367 - valid_acc: 95.4445
# val_acc did not improve from 96.1111
# Epoch: 036 - train_loss: 0.0088 - train_acc: 100.0000 - valid_loss: 0.1350 - valid_acc: 95.6667
# val_acc did not improve from 96.1111
# Epoch: 037 - train_loss: 0.0083 - train_acc: 100.0000 - valid_loss: 0.1413 - valid_acc: 95.4445
# val_acc did not improve from 96.1111
# Epoch: 038 - train_loss: 0.0082 - train_acc: 100.0000 - valid_loss: 0.1421 - valid_acc: 95.5556
# val_acc did not improve from 96.1111
# Epoch: 039 - train_loss: 0.0080 - train_acc: 100.0000 - valid_loss: 0.1355 - valid_acc: 95.5556
# val_acc did not improve from 96.1111
# Epoch: 040 - train_loss: 0.0078 - train_acc: 100.0000 - valid_loss: 0.1442 - valid_acc: 95.5556
# val_acc did not improve from 96.1111
# Epoch: 041 - train_loss: 0.0075 - train_acc: 100.0000 - valid_loss: 0.1438 - valid_acc: 95.4445
# val_acc did not improve from 96.1111
# Epoch: 042 - train_loss: 0.0072 - train_acc: 100.0000 - valid_loss: 0.1420 - valid_acc: 95.3333
# val_acc did not improve from 96.1111
# Epoch: 043 - train_loss: 0.0068 - train_acc: 100.0000 - valid_loss: 0.1419 - valid_acc: 95.4445
# val_acc did not improve from 96.1111
# Epoch: 044 - train_loss: 0.0067 - train_acc: 100.0000 - valid_loss: 0.1391 - valid_acc: 95.5556
# val_acc did not improve from 96.1111
# Epoch: 045 - train_loss: 0.0067 - train_acc: 100.0000 - valid_loss: 0.1414 - valid_acc: 95.4445
# val_acc did not improve from 96.1111
# Epoch: 046 - train_loss: 0.0064 - train_acc: 100.0000 - valid_loss: 0.1437 - valid_acc: 95.4445
# val_acc did not improve from 96.1111
# Epoch: 047 - train_loss: 0.0062 - train_acc: 100.0000 - valid_loss: 0.1443 - valid_acc: 95.4445
# val_acc did not improve from 96.1111
# Epoch: 048 - train_loss: 0.0061 - train_acc: 100.0000 - valid_loss: 0.1416 - valid_acc: 95.5556
# val_acc did not improve from 96.1111
# Epoch: 049 - train_loss: 0.0059 - train_acc: 100.0000 - valid_loss: 0.1393 - valid_acc: 95.4445
# val_acc did not improve from 96.1111
# Epoch: 050 - train_loss: 0.0058 - train_acc: 100.0000 - valid_loss: 0.1506 - valid_acc: 95.4445
# val_acc did not improve from 96.1111
# Epoch: 051 - train_loss: 0.0057 - train_acc: 100.0000 - valid_loss: 0.1530 - valid_acc: 95.3333
# val_acc did not improve from 96.1111
# Epoch: 052 - train_loss: 0.0055 - train_acc: 100.0000 - valid_loss: 0.1503 - valid_acc: 95.4445
# val_acc did not improve from 96.1111
# Epoch: 053 - train_loss: 0.0054 - train_acc: 100.0000 - valid_loss: 0.1449 - valid_acc: 95.4445
# val_acc did not improve from 96.1111
# Epoch: 054 - train_loss: 0.0052 - train_acc: 100.0000 - valid_loss: 0.1415 - valid_acc: 95.6667
# val_acc did not improve from 96.1111
# Epoch: 055 - train_loss: 0.0051 - train_acc: 100.0000 - valid_loss: 0.1508 - valid_acc: 95.4445
# val_acc did not improve from 96.1111
# Epoch: 056 - train_loss: 0.0050 - train_acc: 100.0000 - valid_loss: 0.1587 - valid_acc: 95.3333
# val_acc did not improve from 96.1111
# Epoch: 057 - train_loss: 0.0049 - train_acc: 100.0000 - valid_loss: 0.1559 - valid_acc: 95.4445
# val_acc did not improve from 96.1111
# Epoch: 058 - train_loss: 0.0047 - train_acc: 100.0000 - valid_loss: 0.1541 - valid_acc: 95.4445
# val_acc did not improve from 96.1111
# Epoch: 059 - train_loss: 0.0046 - train_acc: 100.0000 - valid_loss: 0.1516 - valid_acc: 95.4445
# val_acc did not improve from 96.1111
# Epoch: 060 - train_loss: 0.0046 - train_acc: 100.0000 - valid_loss: 0.1497 - valid_acc: 95.4445
# val_acc did not improve from 96.1111
# Epoch: 061 - train_loss: 0.0045 - train_acc: 100.0000 - valid_loss: 0.1514 - valid_acc: 95.4445
# val_acc did not improve from 96.1111
# Epoch: 062 - train_loss: 0.0045 - train_acc: 100.0000 - valid_loss: 0.1474 - valid_acc: 95.7778
# val_acc did not improve from 96.1111
# Epoch: 063 - train_loss: 0.0043 - train_acc: 100.0000 - valid_loss: 0.1427 - valid_acc: 95.7778
# val_acc did not improve from 96.1111
# Epoch: 064 - train_loss: 0.0044 - train_acc: 100.0000 - valid_loss: 0.1441 - valid_acc: 95.7778
# val_acc did not improve from 96.1111
# Epoch: 065 - train_loss: 0.0041 - train_acc: 100.0000 - valid_loss: 0.1483 - valid_acc: 95.7778
# val_acc did not improve from 96.1111
# Epoch: 066 - train_loss: 0.0041 - train_acc: 100.0000 - valid_loss: 0.1500 - valid_acc: 95.6667
# val_acc did not improve from 96.1111
# Epoch: 067 - train_loss: 0.0039 - train_acc: 100.0000 - valid_loss: 0.1471 - valid_acc: 95.6667
# val_acc did not improve from 96.1111
# Epoch: 068 - train_loss: 0.0039 - train_acc: 100.0000 - valid_loss: 0.1459 - valid_acc: 95.7778
# val_acc did not improve from 96.1111
# Epoch: 069 - train_loss: 0.0039 - train_acc: 100.0000 - valid_loss: 0.1473 - valid_acc: 95.6667
# val_acc did not improve from 96.1111
# Epoch: 070 - train_loss: 0.0039 - train_acc: 100.0000 - valid_loss: 0.1477 - valid_acc: 95.6667
# val_acc did not improve from 96.1111
# Epoch: 071 - train_loss: 0.0037 - train_acc: 100.0000 - valid_loss: 0.1529 - valid_acc: 95.5556
# val_acc did not improve from 96.1111
# Epoch: 072 - train_loss: 0.0038 - train_acc: 100.0000 - valid_loss: 0.1561 - valid_acc: 95.4445
# val_acc did not improve from 96.1111
# Epoch: 073 - train_loss: 0.0036 - train_acc: 100.0000 - valid_loss: 0.1559 - valid_acc: 95.4445
# val_acc did not improve from 96.1111
# Epoch: 074 - train_loss: 0.0035 - train_acc: 100.0000 - valid_loss: 0.1511 - valid_acc: 95.6667
# val_acc did not improve from 96.1111
# Epoch: 075 - train_loss: 0.0036 - train_acc: 100.0000 - valid_loss: 0.1464 - valid_acc: 95.7778
# val_acc did not improve from 96.1111
# Epoch: 076 - train_loss: 0.0035 - train_acc: 100.0000 - valid_loss: 0.1477 - valid_acc: 95.7778
# val_acc did not improve from 96.1111
# Epoch: 077 - train_loss: 0.0035 - train_acc: 100.0000 - valid_loss: 0.1485 - valid_acc: 95.6667
# val_acc did not improve from 96.1111
# Epoch: 078 - train_loss: 0.0034 - train_acc: 100.0000 - valid_loss: 0.1547 - valid_acc: 95.4445
# val_acc did not improve from 96.1111
# Epoch: 079 - train_loss: 0.0033 - train_acc: 100.0000 - valid_loss: 0.1576 - valid_acc: 95.3333
# val_acc did not improve from 96.1111
# Epoch: 080 - train_loss: 0.0032 - train_acc: 100.0000 - valid_loss: 0.1569 - valid_acc: 95.4445
# val_acc did not improve from 96.1111
# Epoch: 081 - train_loss: 0.0032 - train_acc: 100.0000 - valid_loss: 0.1569 - valid_acc: 95.4445
# val_acc did not improve from 96.1111
# Epoch: 082 - train_loss: 0.0031 - train_acc: 100.0000 - valid_loss: 0.1584 - valid_acc: 95.4445
# val_acc did not improve from 96.1111
# Epoch: 083 - train_loss: 0.0031 - train_acc: 100.0000 - valid_loss: 0.1554 - valid_acc: 95.5556
# val_acc did not improve from 96.1111
# Epoch: 084 - train_loss: 0.0030 - train_acc: 100.0000 - valid_loss: 0.1531 - valid_acc: 95.5556
# val_acc did not improve from 96.1111
# Epoch: 085 - train_loss: 0.0031 - train_acc: 100.0000 - valid_loss: 0.1513 - valid_acc: 95.7778
# val_acc did not improve from 96.1111
# Epoch: 086 - train_loss: 0.0030 - train_acc: 100.0000 - valid_loss: 0.1512 - valid_acc: 95.7778
# val_acc did not improve from 96.1111
# Epoch: 087 - train_loss: 0.0030 - train_acc: 100.0000 - valid_loss: 0.1521 - valid_acc: 95.8889
# val_acc did not improve from 96.1111
# Epoch: 088 - train_loss: 0.0028 - train_acc: 100.0000 - valid_loss: 0.1539 - valid_acc: 95.6667
# val_acc did not improve from 96.1111
# Epoch: 089 - train_loss: 0.0029 - train_acc: 100.0000 - valid_loss: 0.1551 - valid_acc: 95.6667
# val_acc did not improve from 96.1111
# Epoch: 090 - train_loss: 0.0028 - train_acc: 100.0000 - valid_loss: 0.1569 - valid_acc: 95.5556
# val_acc did not improve from 96.1111
# Epoch: 091 - train_loss: 0.0028 - train_acc: 100.0000 - valid_loss: 0.1577 - valid_acc: 95.5556
# val_acc did not improve from 96.1111
# Epoch: 092 - train_loss: 0.0028 - train_acc: 100.0000 - valid_loss: 0.1553 - valid_acc: 95.7778
# val_acc did not improve from 96.1111
# Epoch: 093 - train_loss: 0.0028 - train_acc: 100.0000 - valid_loss: 0.1538 - valid_acc: 95.7778
# val_acc did not improve from 96.1111
# Epoch: 094 - train_loss: 0.0027 - train_acc: 100.0000 - valid_loss: 0.1528 - valid_acc: 95.8889
# val_acc did not improve from 96.1111
# Epoch: 095 - train_loss: 0.0027 - train_acc: 100.0000 - valid_loss: 0.1530 - valid_acc: 95.7778
# val_acc did not improve from 96.1111
# Epoch: 096 - train_loss: 0.0026 - train_acc: 100.0000 - valid_loss: 0.1545 - valid_acc: 95.6667
# val_acc did not improve from 96.1111
# Epoch: 097 - train_loss: 0.0027 - train_acc: 100.0000 - valid_loss: 0.1550 - valid_acc: 95.7778
# val_acc did not improve from 96.1111
# Epoch: 098 - train_loss: 0.0026 - train_acc: 100.0000 - valid_loss: 0.1547 - valid_acc: 95.7778
# val_acc did not improve from 96.1111
# Epoch: 099 - train_loss: 0.0025 - train_acc: 100.0000 - valid_loss: 0.1554 - valid_acc: 95.7778
# val_acc did not improve from 96.1111
# Epoch: 100 - train_loss: 0.0026 - train_acc: 100.0000 - valid_loss: 0.1570 - valid_acc: 95.7778
# val_acc did not improve from 96.1111
# Running Time: 10.06
# **************************************************

# %%
model.load_state_dict(torch.load(path))
model.eval()

tar_test, pre_test = test(model, test_loader)
OA_test, AA_mean_test, Kappa_test, AA_test = output_metric(tar_test, pre_test)
AA_test = np.around(AA_test*100, 2)

# %%
print("*******************************************************************")
print("Final result:")
print("OA: {:.2f}, AA: {:.2f}, Kappa: {:.4f}".format(OA_test * 100., AA_mean_test*100., Kappa_test))
print("*******************************************************************")
print("Recal: {}".format(AA_test))
print("*******************************************************************")
print("Parameter:")
print_args(vars(args))
print("*******************************************************************")
# Out:
# *******************************************************************
# Final result:
# OA: 96.32, AA: 95.53, Kappa: 0.9512
# *******************************************************************
# Recal: [93.23 98.64 89.05 91.54 99.7  99.78 99.46 90.73 97.61]
# *******************************************************************
# Parameter:
# dataset: Pavia
# seed: 42
# batch_size: 30
# patch_size: 15
# epoches: 100
# learning_rate: 0.001
# gamma: 0.99
# weight_decay: 0.001
# train_number: 25
# *******************************************************************

# %%
average_accuracy = str(list(AA_test))
file_name = "./CR/massformer_1.txt"

with open(file_name, 'w') as x_file:
    x_file.write("[{:.2f}, {:.2f}, {:.4f}]".format(OA_test * 100., AA_mean_test*100., Kappa_test))
    x_file.write('\n')
    x_file.write('{}'.format(average_accuracy))

# %% [markdown]
# ## Panoramic Classification

# %%
def output_label(model, loader):
    model.eval()
    pre = np.array([]).astype('int')
    with torch.no_grad():
        for batch_idx, (batch_data, batch_target) in enumerate(loader):
            batch_data = batch_data.cuda()
            batch_pred = model(batch_data)  # (B, 9)
            _, pred = batch_pred.topk(1, axis=1)  # (B, 1)
            pp = pred.squeeze()
            pre = np.append(pre, pp.data.cpu().numpy())
    return pre

# %%
pos_forward, pos_backward = choose_all_pixels(label)

x_forward, x_backward, y_forward, y_backward = all_data(mirror_data, band, pos_forward, pos_backward, patch_size=args.patch_size)
# Out:
# *******************************************************
# x_forward shape = (42776, 15, 15, 30), type = float64
# x_backward  shape = (164624, 15, 15, 30), type = float64
# *******************************************************

# %%
# load data
x_forward = torch.from_numpy(x_forward.transpose(0, 3, 1, 2)).unsqueeze(1).type(torch.FloatTensor)
print(x_forward.shape)
y_forward = torch.from_numpy(y_forward).type(torch.LongTensor)  # (13,)
forward_label = Data.TensorDataset(x_forward, y_forward)

x_backward = torch.from_numpy(x_backward.transpose(0, 3, 1, 2)).unsqueeze(1).type(torch.FloatTensor)
print(x_backward.shape)
y_backward = torch.from_numpy(y_backward).type(torch.LongTensor)  # (13,)
backward_label = Data.TensorDataset(x_backward, y_backward)

forward_loader = Data.DataLoader(forward_label, batch_size=128, shuffle=False)
backward_loader = Data.DataLoader(backward_label, batch_size=128, shuffle=False)
# Out:
# torch.Size([42776, 1, 30, 15, 15])
# torch.Size([164624, 1, 30, 15, 15])

# %%
# output classification maps
pre_forward = output_label(model, forward_loader)
pre_backward = output_label(model, backward_loader)

prediction_matrix = np.zeros((height, width), dtype=float)  # (512, 614)
for i in range(pos_forward.shape[0]):
    prediction_matrix[pos_forward[i, 0], pos_forward[i, 1]] = pre_forward[i] + 1

for j in range(pos_backward.shape[0]):
    prediction_matrix[pos_backward[j, 0], pos_backward[j, 1]] = pre_backward[j] + 1

# %%
predict_map = list_to_colormap(prediction_matrix.ravel())
predict_map = np.reshape(predict_map, (height, width, 3))

classification_map(predict_map, './pu_massformer.pdf')
