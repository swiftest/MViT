# %%
import os
import time
import argparse
import numpy as np
import scipy.io as sio
import matplotlib as mpl
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler


import torch
import torch.nn as nn
import torch.optim as optim
import torch.utils.data as Data
import torch.backends.cudnn as cudnn


from data_prepare import mirror_hsi
from data_prepare import choose_train_and_test
from data_prepare import choose_all_pixels, all_data
from data_prepare import train_and_test_data, train_and_test_label


import SSFTTnet
from CNNUtils import train, test, valid
from Utils import output_metric, plot_confusion_matrix
from Utils import list_to_colormap, classification_map, print_args


# %matplotlib inline

# %%
parser = argparse.ArgumentParser("SSFTTnet")
parser.add_argument('--dataset', choices=['LongKou', 'HanChuan', 'HongHu', 'HU2013'], default='Pavia', help='dataset to use')
parser.add_argument('--seed', type=int, default=42, help='number of seed')
parser.add_argument('--batch_size', type=int, default=30, help='number of batch size')
parser.add_argument('--patch_size', type=int, default=15, help='size of patches')
parser.add_argument('--epoches', type=int, default=100, help='epoch number')
parser.add_argument('--learning_rate', type=float, default=1e-3, help='learning rate')
parser.add_argument('--gamma', type=float, default=0.99, help='gamma')
parser.add_argument('--weight_decay', type=float, default=0.001, help='weight_decay')
parser.add_argument('--train_number', type=int, default=25, help='num_train_per_class')
args = parser.parse_args(args=[])

# %%
# prepare data
data_path = os.path.join(os.getcwd(), 'dataset')

if args.dataset == 'LongKou':
    data = sio.loadmat(os.path.join(data_path, 'WHU_Hi_LongKou.mat'))['WHU_Hi_LongKou']
    label = sio.loadmat(os.path.join(data_path, 'WHU_Hi_LongKou_gt.mat'))['WHU_Hi_LongKou_gt']
elif args.dataset == 'Pavia':
    data = sio.loadmat(os.path.join(data_path, 'PaviaU.mat'))['paviaU']
    label = sio.loadmat(os.path.join(data_path, 'PaviaU_gt.mat'))['paviaU_gt']
else:
    raise ValueError("Unknown dataset")
    
num_classes = np.max(label)
print('The class numbers of the HSI data is:', num_classes)
# Out:
# The class numbers of the HSI data is: 9

# %%
shapeor = data.shape
data = data.reshape(np.prod(data.shape[:2]), np.prod(data.shape[2:]))

std_scaler = StandardScaler()
std_data = std_scaler.fit_transform(data)
data = std_data.reshape(shapeor)

# %%
def applyPCA(data, numComponents=30):
    new_data = np.reshape(data, (-1, data.shape[2]))
    pca = PCA(n_components=numComponents, whiten=True)
    new_data = pca.fit_transform(new_data)
    new_data = np.reshape(new_data, (data.shape[0], data.shape[1], numComponents))
    return new_data, pca

# %%
K = 30
data, pca = applyPCA(data, numComponents=K)

# data size
height, width, band = data.shape
print("height={0}, width={1}, band={2}".format(height, width, band))
# Out:
# height=610, width=340, band=30

# %%
mirror_data = mirror_hsi(height, width, band, data, patch_size=args.patch_size)
# Out:
# *******************************************************
# patch_size : 15
# mirror_data shape : [624, 354, 30]
# *******************************************************

# %%
total_pos_train, total_pos_test, total_pos_valid, number_train, number_test, number_valid = choose_train_and_test(label, args.train_number, args.seed) 

x_train, x_test, x_valid = train_and_test_data(mirror_data, band, total_pos_train, total_pos_test, total_pos_valid, args.patch_size)
y_train, y_test, y_valid = train_and_test_label(number_train, number_test, number_valid, num_classes)
# Out:
# *******************************************************
# x_train shape = (225, 15, 15, 30), type = float64
# x_test  shape = (42551, 15, 15, 30), type = float64
# x_valid  shape = (900, 15, 15, 30), type = float64
# *******************************************************
# y_train: shape = (225,), type = int64
# y_test: shape = (42551,), type = int64
# y_valid: shape = (900,), type = int64
# *******************************************************

# %%
total_pos_train[:10]
# Out:
# array([[409, 293],
#        [404, 298],
#        [380, 301],
#        [551,  14],
#        [453, 165],
#        [140, 172],
#        [471, 169],
#        [175, 187],
#        [482, 185],
#        [214, 200]])

# %%
# load data
x_train = torch.from_numpy(x_train).unsqueeze(1).type(torch.FloatTensor)  # (90, 1, 7, 7, 176)
print(x_train.shape)
y_train = torch.from_numpy(y_train).type(torch.LongTensor)  # (13,)
train_label = Data.TensorDataset(x_train, y_train)

x_test = torch.from_numpy(x_test).unsqueeze(1).type(torch.FloatTensor)  # (5198, 1, 7, 7, 176)
print(x_test.shape)
y_test = torch.from_numpy(y_test).type(torch.LongTensor)  # (5198,)
test_label = Data.TensorDataset(x_test, y_test)

x_valid = torch.from_numpy(x_valid).unsqueeze(1).type(torch.FloatTensor)  # (5211, 1, 7, 7, 176)
print(x_valid.shape)
y_valid = torch.from_numpy(y_valid).type(torch.LongTensor)
valid_label = Data.TensorDataset(x_valid, y_valid)

train_loader = Data.DataLoader(train_label, batch_size=30, shuffle=True)
test_loader = Data.DataLoader(test_label, batch_size=128, shuffle=True)
valid_loader = Data.DataLoader(valid_label, batch_size=64, shuffle=True)
# Out:
# torch.Size([225, 1, 15, 15, 30])
# torch.Size([42551, 1, 15, 15, 30])
# torch.Size([900, 1, 15, 15, 30])

# %% [markdown]
# # Model

# %%
model = SSFTTnet.SSFTTnet(num_classes=num_classes).cuda()

criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=1e-3, betas=(0.9, 0.999), eps=1e-8, weight_decay=1e-06)
scheduler = optim.lr_scheduler.ExponentialLR(optimizer, gamma=args.gamma)

# %%
print('start training')
acc_list = [0.00]
path = './model/SSFTTnet.pt'
tic = time.time()
for epoch in range(args.epoches):
    # 计算的是移动平均准确率
    train_acc, train_loss = train(model, train_loader, criterion, optimizer)
    valid_acc, valid_loss = valid(model, valid_loader, criterion)
    print("Epoch: {:03d} - train_loss: {:.4f} - train_acc: {:.4f} - valid_loss: {:.4f} - valid_acc: {:.4f}".\
          format(epoch+1, train_loss, train_acc, valid_loss, valid_acc))
    scheduler.step()

    acc_list.append(valid_acc)
    if acc_list[-1] > acc_list[-2]:
        print("val_acc improved from {:.4f} to {:.4f}, saving model to SSFTTnet.pt".format(acc_list[-2], acc_list[-1]))
        torch.save(model.state_dict(), path)
    else:
        print("val_acc did not improve from {:.4f}".format(acc_list[-2]))
        acc_list[-1] = acc_list[-2]

toc = time.time()
print("Running Time: {:.2f}".format(toc-tic))
print("**************************************************")
# Out:
# start training
# Epoch: 001 - train_loss: 1.7349 - train_acc: 43.1111 - valid_loss: 1.4476 - valid_acc: 47.8889
# val_acc improved from 0.0000 to 47.8889, saving model to SSFTTnet.pt
# Epoch: 002 - train_loss: 0.9177 - train_acc: 79.1111 - valid_loss: 0.6592 - valid_acc: 82.8889
# val_acc improved from 47.8889 to 82.8889, saving model to SSFTTnet.pt
# Epoch: 003 - train_loss: 0.4756 - train_acc: 88.8889 - valid_loss: 0.4707 - valid_acc: 83.7778
# val_acc improved from 82.8889 to 83.7778, saving model to SSFTTnet.pt
# Epoch: 004 - train_loss: 0.3198 - train_acc: 88.8889 - valid_loss: 0.3200 - valid_acc: 89.5556
# val_acc improved from 83.7778 to 89.5556, saving model to SSFTTnet.pt
# Epoch: 005 - train_loss: 0.1847 - train_acc: 94.6667 - valid_loss: 0.2124 - valid_acc: 92.0000
# val_acc improved from 89.5556 to 92.0000, saving model to SSFTTnet.pt
# Epoch: 006 - train_loss: 0.1395 - train_acc: 96.0000 - valid_loss: 0.2647 - valid_acc: 90.4445
# val_acc did not improve from 92.0000
# Epoch: 007 - train_loss: 0.1009 - train_acc: 98.6667 - valid_loss: 0.3634 - valid_acc: 89.0000
# val_acc did not improve from 92.0000
# Epoch: 008 - train_loss: 0.0548 - train_acc: 99.1111 - valid_loss: 0.2841 - valid_acc: 90.5556
# val_acc did not improve from 92.0000
# Epoch: 009 - train_loss: 0.0405 - train_acc: 99.5556 - valid_loss: 0.1552 - valid_acc: 93.8889
# val_acc improved from 92.0000 to 93.8889, saving model to SSFTTnet.pt
# Epoch: 010 - train_loss: 0.0336 - train_acc: 99.5556 - valid_loss: 0.1564 - valid_acc: 94.1111
# val_acc improved from 93.8889 to 94.1111, saving model to SSFTTnet.pt
# Epoch: 011 - train_loss: 0.0136 - train_acc: 100.0000 - valid_loss: 0.1848 - valid_acc: 94.3333
# val_acc improved from 94.1111 to 94.3333, saving model to SSFTTnet.pt
# Epoch: 012 - train_loss: 0.0214 - train_acc: 99.5556 - valid_loss: 0.1990 - valid_acc: 93.7778
# val_acc did not improve from 94.3333
# Epoch: 013 - train_loss: 0.0105 - train_acc: 100.0000 - valid_loss: 0.1752 - valid_acc: 94.5556
# val_acc improved from 94.3333 to 94.5556, saving model to SSFTTnet.pt
# Epoch: 014 - train_loss: 0.0147 - train_acc: 100.0000 - valid_loss: 0.1742 - valid_acc: 93.8889
# val_acc did not improve from 94.5556
# Epoch: 015 - train_loss: 0.0071 - train_acc: 100.0000 - valid_loss: 0.1649 - valid_acc: 94.2222
# val_acc did not improve from 94.5556
# Epoch: 016 - train_loss: 0.0099 - train_acc: 100.0000 - valid_loss: 0.1731 - valid_acc: 94.4445
# val_acc did not improve from 94.5556
# Epoch: 017 - train_loss: 0.0062 - train_acc: 100.0000 - valid_loss: 0.2020 - valid_acc: 94.5556
# val_acc did not improve from 94.5556
# Epoch: 018 - train_loss: 0.0079 - train_acc: 100.0000 - valid_loss: 0.1853 - valid_acc: 94.4445
# val_acc did not improve from 94.5556
# Epoch: 019 - train_loss: 0.0077 - train_acc: 100.0000 - valid_loss: 0.1693 - valid_acc: 94.2222
# val_acc did not improve from 94.5556
# Epoch: 020 - train_loss: 0.0059 - train_acc: 100.0000 - valid_loss: 0.1524 - valid_acc: 94.3333
# val_acc did not improve from 94.5556
# Epoch: 021 - train_loss: 0.0035 - train_acc: 100.0000 - valid_loss: 0.1519 - valid_acc: 94.4445
# val_acc did not improve from 94.5556
# Epoch: 022 - train_loss: 0.0046 - train_acc: 100.0000 - valid_loss: 0.1599 - valid_acc: 94.2222
# val_acc did not improve from 94.5556
# Epoch: 023 - train_loss: 0.0034 - train_acc: 100.0000 - valid_loss: 0.1590 - valid_acc: 94.4445
# val_acc did not improve from 94.5556
# Epoch: 024 - train_loss: 0.0027 - train_acc: 100.0000 - valid_loss: 0.1596 - valid_acc: 94.3333
# val_acc did not improve from 94.5556
# Epoch: 025 - train_loss: 0.0033 - train_acc: 100.0000 - valid_loss: 0.1479 - valid_acc: 94.4445
# val_acc did not improve from 94.5556
# Epoch: 026 - train_loss: 0.0040 - train_acc: 100.0000 - valid_loss: 0.1626 - valid_acc: 95.0000
# val_acc improved from 94.5556 to 95.0000, saving model to SSFTTnet.pt
# Epoch: 027 - train_loss: 0.0021 - train_acc: 100.0000 - valid_loss: 0.1649 - valid_acc: 95.0000
# val_acc did not improve from 95.0000
# Epoch: 028 - train_loss: 0.0022 - train_acc: 100.0000 - valid_loss: 0.1510 - valid_acc: 95.0000
# val_acc did not improve from 95.0000
# Epoch: 029 - train_loss: 0.0025 - train_acc: 100.0000 - valid_loss: 0.1433 - valid_acc: 95.2222
# val_acc improved from 95.0000 to 95.2222, saving model to SSFTTnet.pt
# Epoch: 030 - train_loss: 0.0033 - train_acc: 100.0000 - valid_loss: 0.1366 - valid_acc: 95.1111
# val_acc did not improve from 95.2222
# Epoch: 031 - train_loss: 0.0012 - train_acc: 100.0000 - valid_loss: 0.1315 - valid_acc: 95.2222
# val_acc did not improve from 95.2222
# Epoch: 032 - train_loss: 0.0012 - train_acc: 100.0000 - valid_loss: 0.1276 - valid_acc: 95.0000
# val_acc did not improve from 95.2222
# Epoch: 033 - train_loss: 0.0018 - train_acc: 100.0000 - valid_loss: 0.1253 - valid_acc: 95.2222
# val_acc did not improve from 95.2222
# Epoch: 034 - train_loss: 0.0029 - train_acc: 100.0000 - valid_loss: 0.1324 - valid_acc: 95.4445
# val_acc improved from 95.2222 to 95.4445, saving model to SSFTTnet.pt
# Epoch: 035 - train_loss: 0.0026 - train_acc: 100.0000 - valid_loss: 0.2355 - valid_acc: 93.7778
# val_acc did not improve from 95.4445
# Epoch: 036 - train_loss: 0.0013 - train_acc: 100.0000 - valid_loss: 0.2365 - valid_acc: 94.1111
# val_acc did not improve from 95.4445
# Epoch: 037 - train_loss: 0.0023 - train_acc: 100.0000 - valid_loss: 0.1845 - valid_acc: 94.7778
# val_acc did not improve from 95.4445
# Epoch: 038 - train_loss: 0.0011 - train_acc: 100.0000 - valid_loss: 0.1402 - valid_acc: 96.0000
# val_acc improved from 95.4445 to 96.0000, saving model to SSFTTnet.pt
# Epoch: 039 - train_loss: 0.0017 - train_acc: 100.0000 - valid_loss: 0.1352 - valid_acc: 96.1111
# val_acc improved from 96.0000 to 96.1111, saving model to SSFTTnet.pt
# Epoch: 040 - train_loss: 0.0015 - train_acc: 100.0000 - valid_loss: 0.1400 - valid_acc: 95.3333
# val_acc did not improve from 96.1111
# Epoch: 041 - train_loss: 0.0017 - train_acc: 100.0000 - valid_loss: 0.1393 - valid_acc: 95.1111
# val_acc did not improve from 96.1111
# Epoch: 042 - train_loss: 0.0008 - train_acc: 100.0000 - valid_loss: 0.1408 - valid_acc: 95.0000
# val_acc did not improve from 96.1111
# Epoch: 043 - train_loss: 0.0008 - train_acc: 100.0000 - valid_loss: 0.1383 - valid_acc: 94.7778
# val_acc did not improve from 96.1111
# Epoch: 044 - train_loss: 0.0054 - train_acc: 100.0000 - valid_loss: 0.1421 - valid_acc: 94.7778
# val_acc did not improve from 96.1111
# Epoch: 045 - train_loss: 0.0020 - train_acc: 100.0000 - valid_loss: 0.1513 - valid_acc: 94.6667
# val_acc did not improve from 96.1111
# Epoch: 046 - train_loss: 0.0075 - train_acc: 100.0000 - valid_loss: 0.1506 - valid_acc: 94.5556
# val_acc did not improve from 96.1111
# Epoch: 047 - train_loss: 0.0016 - train_acc: 100.0000 - valid_loss: 0.1782 - valid_acc: 94.5556
# val_acc did not improve from 96.1111
# Epoch: 048 - train_loss: 0.0026 - train_acc: 100.0000 - valid_loss: 0.1917 - valid_acc: 94.7778
# val_acc did not improve from 96.1111
# Epoch: 049 - train_loss: 0.0086 - train_acc: 99.5556 - valid_loss: 0.2138 - valid_acc: 94.5556
# val_acc did not improve from 96.1111
# Epoch: 050 - train_loss: 0.0041 - train_acc: 100.0000 - valid_loss: 0.1966 - valid_acc: 94.4445
# val_acc did not improve from 96.1111
# Epoch: 051 - train_loss: 0.0048 - train_acc: 100.0000 - valid_loss: 0.3107 - valid_acc: 91.0000
# val_acc did not improve from 96.1111
# Epoch: 052 - train_loss: 0.0023 - train_acc: 100.0000 - valid_loss: 0.2452 - valid_acc: 92.7778
# val_acc did not improve from 96.1111
# Epoch: 053 - train_loss: 0.0042 - train_acc: 100.0000 - valid_loss: 0.1836 - valid_acc: 93.7778
# val_acc did not improve from 96.1111
# Epoch: 054 - train_loss: 0.0214 - train_acc: 99.5556 - valid_loss: 0.2890 - valid_acc: 91.3333
# val_acc did not improve from 96.1111
# Epoch: 055 - train_loss: 0.0035 - train_acc: 100.0000 - valid_loss: 0.5381 - valid_acc: 88.2222
# val_acc did not improve from 96.1111
# Epoch: 056 - train_loss: 0.0031 - train_acc: 100.0000 - valid_loss: 0.4001 - valid_acc: 91.6667
# val_acc did not improve from 96.1111
# Epoch: 057 - train_loss: 0.0027 - train_acc: 100.0000 - valid_loss: 0.2743 - valid_acc: 93.0000
# val_acc did not improve from 96.1111
# Epoch: 058 - train_loss: 0.0013 - train_acc: 100.0000 - valid_loss: 0.2343 - valid_acc: 93.4445
# val_acc did not improve from 96.1111
# Epoch: 059 - train_loss: 0.0022 - train_acc: 100.0000 - valid_loss: 0.2272 - valid_acc: 92.8889
# val_acc did not improve from 96.1111
# Epoch: 060 - train_loss: 0.0012 - train_acc: 100.0000 - valid_loss: 0.2181 - valid_acc: 93.1111
# val_acc did not improve from 96.1111
# Epoch: 061 - train_loss: 0.0013 - train_acc: 100.0000 - valid_loss: 0.2250 - valid_acc: 92.8889
# val_acc did not improve from 96.1111
# Epoch: 062 - train_loss: 0.0011 - train_acc: 100.0000 - valid_loss: 0.2151 - valid_acc: 93.1111
# val_acc did not improve from 96.1111
# Epoch: 063 - train_loss: 0.0012 - train_acc: 100.0000 - valid_loss: 0.2073 - valid_acc: 93.3333
# val_acc did not improve from 96.1111
# Epoch: 064 - train_loss: 0.0008 - train_acc: 100.0000 - valid_loss: 0.1903 - valid_acc: 94.3333
# val_acc did not improve from 96.1111
# Epoch: 065 - train_loss: 0.0010 - train_acc: 100.0000 - valid_loss: 0.1860 - valid_acc: 94.6667
# val_acc did not improve from 96.1111
# Epoch: 066 - train_loss: 0.0013 - train_acc: 100.0000 - valid_loss: 0.1868 - valid_acc: 94.1111
# val_acc did not improve from 96.1111
# Epoch: 067 - train_loss: 0.0009 - train_acc: 100.0000 - valid_loss: 0.1941 - valid_acc: 93.7778
# val_acc did not improve from 96.1111
# Epoch: 068 - train_loss: 0.0011 - train_acc: 100.0000 - valid_loss: 0.1905 - valid_acc: 94.0000
# val_acc did not improve from 96.1111
# Epoch: 069 - train_loss: 0.0014 - train_acc: 100.0000 - valid_loss: 0.1910 - valid_acc: 93.6667
# val_acc did not improve from 96.1111
# Epoch: 070 - train_loss: 0.0005 - train_acc: 100.0000 - valid_loss: 0.2068 - valid_acc: 93.2222
# val_acc did not improve from 96.1111
# Epoch: 071 - train_loss: 0.0005 - train_acc: 100.0000 - valid_loss: 0.1943 - valid_acc: 94.1111
# val_acc did not improve from 96.1111
# Epoch: 072 - train_loss: 0.0017 - train_acc: 100.0000 - valid_loss: 0.2019 - valid_acc: 93.8889
# val_acc did not improve from 96.1111
# Epoch: 073 - train_loss: 0.0006 - train_acc: 100.0000 - valid_loss: 0.2271 - valid_acc: 93.2222
# val_acc did not improve from 96.1111
# Epoch: 074 - train_loss: 0.0012 - train_acc: 100.0000 - valid_loss: 0.2242 - valid_acc: 93.0000
# val_acc did not improve from 96.1111
# Epoch: 075 - train_loss: 0.0010 - train_acc: 100.0000 - valid_loss: 0.2344 - valid_acc: 92.8889
# val_acc did not improve from 96.1111
# Epoch: 076 - train_loss: 0.0008 - train_acc: 100.0000 - valid_loss: 0.2127 - valid_acc: 92.7778
# val_acc did not improve from 96.1111
# Epoch: 077 - train_loss: 0.0005 - train_acc: 100.0000 - valid_loss: 0.1910 - valid_acc: 93.5556
# val_acc did not improve from 96.1111
# Epoch: 078 - train_loss: 0.0009 - train_acc: 100.0000 - valid_loss: 0.1842 - valid_acc: 93.2222
# val_acc did not improve from 96.1111
# Epoch: 079 - train_loss: 0.0005 - train_acc: 100.0000 - valid_loss: 0.1908 - valid_acc: 93.3333
# val_acc did not improve from 96.1111
# Epoch: 080 - train_loss: 0.0005 - train_acc: 100.0000 - valid_loss: 0.1946 - valid_acc: 93.1111
# val_acc did not improve from 96.1111
# Epoch: 081 - train_loss: 0.0011 - train_acc: 100.0000 - valid_loss: 0.1830 - valid_acc: 93.6667
# val_acc did not improve from 96.1111
# Epoch: 082 - train_loss: 0.0005 - train_acc: 100.0000 - valid_loss: 0.1801 - valid_acc: 93.8889
# val_acc did not improve from 96.1111
# Epoch: 083 - train_loss: 0.0005 - train_acc: 100.0000 - valid_loss: 0.1729 - valid_acc: 94.2222
# val_acc did not improve from 96.1111
# Epoch: 084 - train_loss: 0.0006 - train_acc: 100.0000 - valid_loss: 0.1779 - valid_acc: 94.0000
# val_acc did not improve from 96.1111
# Epoch: 085 - train_loss: 0.0004 - train_acc: 100.0000 - valid_loss: 0.1796 - valid_acc: 94.3333
# val_acc did not improve from 96.1111
# Epoch: 086 - train_loss: 0.0003 - train_acc: 100.0000 - valid_loss: 0.1720 - valid_acc: 94.2222
# val_acc did not improve from 96.1111
# Epoch: 087 - train_loss: 0.0004 - train_acc: 100.0000 - valid_loss: 0.1836 - valid_acc: 94.0000
# val_acc did not improve from 96.1111
# Epoch: 088 - train_loss: 0.0005 - train_acc: 100.0000 - valid_loss: 0.1786 - valid_acc: 94.2222
# val_acc did not improve from 96.1111
# Epoch: 089 - train_loss: 0.0004 - train_acc: 100.0000 - valid_loss: 0.1723 - valid_acc: 94.5556
# val_acc did not improve from 96.1111
# Epoch: 090 - train_loss: 0.0003 - train_acc: 100.0000 - valid_loss: 0.1666 - valid_acc: 94.4445
# val_acc did not improve from 96.1111
# Epoch: 091 - train_loss: 0.0004 - train_acc: 100.0000 - valid_loss: 0.1784 - valid_acc: 94.4445
# val_acc did not improve from 96.1111
# Epoch: 092 - train_loss: 0.0003 - train_acc: 100.0000 - valid_loss: 0.1651 - valid_acc: 94.5556
# val_acc did not improve from 96.1111
# Epoch: 093 - train_loss: 0.0004 - train_acc: 100.0000 - valid_loss: 0.1723 - valid_acc: 94.3333
# val_acc did not improve from 96.1111
# Epoch: 094 - train_loss: 0.0003 - train_acc: 100.0000 - valid_loss: 0.1716 - valid_acc: 94.3333
# val_acc did not improve from 96.1111
# Epoch: 095 - train_loss: 0.0005 - train_acc: 100.0000 - valid_loss: 0.1800 - valid_acc: 94.0000
# val_acc did not improve from 96.1111
# Epoch: 096 - train_loss: 0.0003 - train_acc: 100.0000 - valid_loss: 0.1715 - valid_acc: 94.2222
# val_acc did not improve from 96.1111
# Epoch: 097 - train_loss: 0.0002 - train_acc: 100.0000 - valid_loss: 0.1707 - valid_acc: 94.1111
# val_acc did not improve from 96.1111
# Epoch: 098 - train_loss: 0.0003 - train_acc: 100.0000 - valid_loss: 0.1770 - valid_acc: 94.1111
# val_acc did not improve from 96.1111
# Epoch: 099 - train_loss: 0.0003 - train_acc: 100.0000 - valid_loss: 0.1813 - valid_acc: 94.1111
# val_acc did not improve from 96.1111
# Epoch: 100 - train_loss: 0.0006 - train_acc: 100.0000 - valid_loss: 0.1730 - valid_acc: 94.2222
# val_acc did not improve from 96.1111
# Running Time: 8.89
# **************************************************

# %%
model.load_state_dict(torch.load(path))
model.eval()

tar_test, pre_test = test(model, test_loader)
OA_test, AA_mean_test, Kappa_test, AA_test = output_metric(tar_test, pre_test)
AA_test = np.around(AA_test*100, 2)

# %%
print("*******************************************************************")
print("Final result:")
print("OA: {:.2f}, AA: {:.2f}, Kappa: {:.4f}".format(OA_test * 100., AA_mean_test*100., Kappa_test))
print("*******************************************************************")
print("Recal: {}".format(AA_test))
print("*******************************************************************")
print("Parameter:")
print_args(vars(args))
print("*******************************************************************")
# Out:
# *******************************************************************
# Final result:
# OA: 95.44, AA: 95.69, Kappa: 0.9398
# *******************************************************************
# Recal: [ 89.49  97.2   92.43  95.43  99.7   99.62 100.    89.47  97.83]
# *******************************************************************
# Parameter:
# dataset: Pavia
# seed: 42
# batch_size: 30
# patch_size: 15
# epoches: 100
# learning_rate: 0.001
# gamma: 0.99
# weight_decay: 0.001
# train_number: 25
# *******************************************************************

# %%
average_accuracy = str(list(AA_test))
file_name = "./CR/ssftt_1.txt"

with open(file_name, 'w') as x_file:
    x_file.write("[{:.2f}, {:.2f}, {:.4f}]".format(OA_test * 100., AA_mean_test*100., Kappa_test))
    x_file.write('\n')
    x_file.write('{}'.format(average_accuracy))

# %% [markdown]
# ## Panoramic Classification

# %%
def output_label(model, loader):
    model.eval()
    pre = np.array([]).astype('int')
    with torch.no_grad():
        for batch_idx, (batch_data, batch_target) in enumerate(loader):
            batch_data = batch_data.cuda()
            batch_pred = model(batch_data)  # (B, 9)
            _, pred = batch_pred.topk(1, axis=1)  # (B, 1)
            pp = pred.squeeze()
            pre = np.append(pre, pp.data.cpu().numpy())
    return pre

# %%
pos_forward, pos_backward = choose_all_pixels(label)

x_forward, x_backward, y_forward, y_backward = all_data(mirror_data, band, pos_forward, pos_backward, patch_size=args.patch_size)
# Out:
# *******************************************************
# x_forward shape = (42776, 15, 15, 30), type = float64
# x_backward  shape = (164624, 15, 15, 30), type = float64
# *******************************************************

# %%
# load data
x_forward = torch.from_numpy(x_forward).unsqueeze(1).type(torch.FloatTensor)
print(x_forward.shape)
y_forward = torch.from_numpy(y_forward).type(torch.LongTensor)  # (13,)
forward_label = Data.TensorDataset(x_forward, y_forward)

x_backward = torch.from_numpy(x_backward).unsqueeze(1).type(torch.FloatTensor)
print(x_backward.shape)
y_backward = torch.from_numpy(y_backward).type(torch.LongTensor)  # (13,)
backward_label = Data.TensorDataset(x_backward, y_backward)

forward_loader = Data.DataLoader(forward_label, batch_size=128, shuffle=False)
backward_loader = Data.DataLoader(backward_label, batch_size=128, shuffle=False)
# Out:
# torch.Size([42776, 1, 15, 15, 30])
# torch.Size([164624, 1, 15, 15, 30])

# %%
# output classification maps
pre_forward = output_label(model, forward_loader)
pre_backward = output_label(model, backward_loader)

prediction_matrix = np.zeros((height, width), dtype=float)  # (512, 614)
for i in range(pos_forward.shape[0]):
    prediction_matrix[pos_forward[i, 0], pos_forward[i, 1]] = pre_forward[i] + 1

for j in range(pos_backward.shape[0]):
    prediction_matrix[pos_backward[j, 0], pos_backward[j, 1]] = pre_backward[j] + 1

# %%
predict_map = list_to_colormap(prediction_matrix.ravel())
predict_map = np.reshape(predict_map, (height, width, 3))

classification_map(predict_map, './pu_ssftt.pdf')
